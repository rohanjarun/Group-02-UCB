# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('CMO-Monthly-Prices_Clean.csv')
df.tail()
# Out:
#     Unnamed: 0  Crude oil, average  Crude oil, Brent  Crude oil, Dubai  \
# 748    2022M05              110.10            112.37            108.32
# 749    2022M06              116.80            120.08            115.73
# 750    2022M07              105.08            108.92            106.48
# 751    2022M08               95.97             98.60             97.75
# 752    2022M09               88.22             90.16             90.63
#
#      Crude oil, WTI  Coal, Australian  Coal, South African **  \
# 748          109.60               NaN                  280.00
# 749          114.59               NaN                  313.46
# 750           99.85               NaN                  329.82
# 751           91.57               NaN                  318.28
# 752           83.87               NaN                  321.48
#
#      Natural gas, US  Natural gas, Europe **  Liquefied natural gas, Japan  \
# 748             8.14                   29.17                         16.68
# 749             7.67                   33.56                         15.53
# 750             7.26                   51.33                         18.88
# 751             8.79                   70.04                         21.21
# 752             7.76                   59.10                         21.70
#
#      ...  Aluminum  Iron ore, cfr spot   Copper     Lead       Tin    Nickel  \
# 748  ...   2830.32              131.21  9377.15  2142.48  35769.39  28062.55
# 749  ...   2563.44              130.74  9024.46  2066.38  31559.31  25658.63
# 750  ...   2408.42              108.57  7544.81  1985.20  25395.77  21481.89
# 751  ...   2430.79              108.85  7981.84  2072.72  24647.48  22057.39
# 752  ...   2228.09               99.80  7749.00  1868.10  21145.47  22857.87
#
#         Zinc     Gold  Platinum  Silver
# 748  3751.48  1848.50    958.38   21.91
# 749  3629.73  1836.57    956.59   21.56
# 750  3105.36  1732.74    869.25   19.08
# 751  3587.57  1764.56    908.65   19.72
# 752  3130.24  1680.78    881.24   18.94
#
# [5 rows x 72 columns]

# %%
df = pd.read_csv('US_Fed_IDV_contracts_Clean.csv')
df.head()
# Out:
#             Award ID Start Date  Award Amount  \
# 0  15UC0C20D00001857  8/25/2025   50000000.00
# 1      36C10X21D0002   8/3/2021      19167.00
# 2  15BRRC21D00000274   3/1/2021      15974.19
# 3      19AQMM21D0011  2/12/2021      10000.00
# 4      19AQMM21D0010  2/12/2021      10000.00
#
#                       Recipient Name  \
# 0  VETERANS ENVIRONMENTAL GROUP, LLC
# 1      CARDINAL HEALTH P.R. 220, LLC
# 2              DISMAS CHARITIES, INC
# 3                  TRIPLE CANOPY INC
# 4                            SOC LLC
#
#                                          Description  \
# 0  SUSTAINING AND MAINTAINING TRAINING LANDS, PRO...
# 1  MEDICAL/SURGICAL PRIME VENDOR (MSPV) 2.0 IDIQ ...
# 2          TO PROVIDE RRC SERVICE IN ALBUQUERQUE, NM
# 3  PROFESSIONAL SECURITY SERVICES CONTRACT WORLDW...
# 4  WORLDWIDE PROTECTIVE SERVICES (WPS) III MULTIP...
#
#                          Contract Award Type def_codes  \
# 0         INDEFINITE DELIVERY / REQUIREMENTS       NaN
# 1  INDEFINITE DELIVERY / INDEFINITE QUANTITY       NaN
# 2  INDEFINITE DELIVERY / INDEFINITE QUANTITY       NaN
# 3  INDEFINITE DELIVERY / INDEFINITE QUANTITY       NaN
# 4  INDEFINITE DELIVERY / INDEFINITE QUANTITY       NaN
#
#                   Awarding Agency                        Awarding Sub Agency  \
# 0           Department of Justice         Federal Prison Industries / Unicor
# 1  Department of Veterans Affairs             Department of Veterans Affairs
# 2           Department of Justice  Federal Prison System / Bureau of Prisons
# 3             Department of State                        Department of State
# 4             Department of State                        Department of State
#
#    awarding_agency_id                     agency_slug  \
# 0               252.0           department-of-justice
# 1               561.0  department-of-veterans-affairs
# 2               252.0           department-of-justice
# 3               315.0             department-of-state
# 4               315.0             department-of-state
#
#              generated_internal_id  Unnamed: 13    Month
# 0  CONT_IDV_15UC0C20D00001857_1542          NaN  2025M08
# 1      CONT_IDV_36C10X21D0002_3600          NaN  2021M08
# 2  CONT_IDV_15BRRC21D00000274_1540          NaN  2021M03
# 3      CONT_IDV_19AQMM21D0011_1900          NaN  2021M02
# 4      CONT_IDV_19AQMM21D0010_1900          NaN  2021M02

# %%
# ML Spending & Result

# %%
import scipy.stats as st

corr=round(st.pearsonr(final_combined_data_df['player count'],final_combined_data_df['Final Price_$'])[0],2)
# player count = US Spending | Final Price = Natural Gas Price
print(f"The correlation between Player Count and Final Price is {corr}")
model = st.linregress(final_combined_data_df['player count'],final_combined_data_df['Final Price_$'])

y_values = final_combined_data_df['player count']*model[0]+model[1]
plt.scatter(final_combined_data_df['player count'],final_combined_data_df['Final Price_$'])
plt.plot(final_combined_data_df['player count'],y_values,color="red")
plt.xlabel('Player Count')
plt.ylabel('Final Price')
plt.show()

# %%
players_prices_df = final_combined_data_df.loc[:, ['player count', 'Final Price_$']]

# %%
corr = players_prices_df.corr()

# %%
corr.style.background_gradient(cmap ='coolwarm')

# %%
from scipy import stats

t_stat, p_val = stats.ttest_ind(final_combined_data_df['player count'],final_combined_data_df['Final Price_$'], 
                      equal_var=False, alternative='less')
print(f"t is {t_stat:.2f} while p is {p_val:.6f}")
if p_val < 0.05:
    print('Null hypothesis is rejected and Alternative Hypothesis is true.')
else:
    print('P = 0.99 and is > 0.05 so the Null Hypothesis is true.')

# %%
Hypothesis - If the number of players in a game is related to the price of a game, then price is a factor of game popularity.
Null Hypothesis - Price of a game is NOT a factor in game popularity.
Alternative Hypothesis - Price of a game is a factor in game popularity.
