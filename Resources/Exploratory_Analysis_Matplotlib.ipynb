# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies & Setup
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import linregress
import numpy as np
from matplotlib.pyplot import pie, axis, show

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Files to load
energy_contracts_to_load = "/content/drive/MyDrive/ResourcesUCB/clean_contracts.csv"
clean_indices_to_load = "/content/drive/MyDrive/ResourcesUCB/clean_indices.csv"
clean_prices_to_load = "/content/drive/MyDrive/ResourcesUCB/clean_prices.csv"
other_natural_gas_to_load = "/content/drive/MyDrive/ResourcesUCB/other_natural_gas_data_df.csv"
other_natural_gas_10_to_load = "/content/drive/MyDrive/ResourcesUCB/other_natural_gas_data_10_df.csv"
other_natural_gas_5_to_load = "/content/drive/MyDrive/ResourcesUCB/other_natural_gas_data_5_df.csv"

# %%
# Read files & store in pandas DataFrame
energy_contracts_df = pd.read_csv(energy_contracts_to_load)
indices_df = pd.read_csv(clean_indices_to_load)
prices_df = pd.read_csv(clean_prices_to_load)
other_natural_gas_df = pd.read_csv(other_natural_gas_to_load)
other_natural_gas_10_df = pd.read_csv(other_natural_gas_10_to_load)
other_natural_gas_5_df = pd.read_csv(other_natural_gas_5_to_load)

# %%
energy_contracts_df.head()
# Out:
#    total_obligated_amount    Month    product_or_service_code_description  \
# 0                10000.00  2016M09        GASES: COMPRESSED AND LIQUEFIED
# 1                 1384.98  2016M02   MINERAL CONSTRUCTION MATERIALS, BULK
# 2               542491.46  2017M05  MAINTENANCE OF FUEL SUPPLY FACILITIES
# 3                21764.63  2016M03   OTHER QC/TEST/INSPECT- MISCELLANEOUS
# 4               256800.00  2020M12   MINERAL CONSTRUCTION MATERIALS, BULK
#
#                                    naics_description  \
# 0                      NATURAL GAS LIQUID EXTRACTION
# 1                CONSTRUCTION SAND AND GRAVEL MINING
# 2      SUPPORT ACTIVITIES FOR OIL AND GAS OPERATIONS
# 3                CONSTRUCTION SAND AND GRAVEL MINING
# 4  OTHER CRUSHED AND BROKEN STONE MINING AND QUAR...
#
#                    recipient_name   funding_sub_agency_name
# 0          AMERIGAS PROPANE, L.P.          DEPT OF THE NAVY
# 1      BRAATEN SAND & GRAVEL, INC     FEDERAL PRISON SYSTEM
# 2          POND CONSTRUCTORS, INC  DEFENSE LOGISTICS AGENCY
# 3  MISCELLANEOUS FOREIGN AWARDEES      STATE, DEPARTMENT OF
# 4  FOREIGN AWARDEES (UNDISCLOSED)          DEPT OF THE ARMY

# %%
indices_df.head()
# Out:
#      Month  Energy  Non_Energy  Agriculture  Agriculture_Beverages  \
# 0  2016M01   40.86       74.03        82.30                  86.05
# 1  2016M02   42.84       74.60        82.53                  84.82
# 2  2016M03   48.74       76.99        84.41                  88.42
# 3  2016M04   52.28       78.83        86.89                  89.81
# 4  2016M05   57.65       79.95        89.62                  90.92
#
#    Agriculture_Food  Agriculture_Oils_Meals  Agriculture_Grains  \
# 0             83.11                   77.99               82.77
# 1             83.82                   79.84               82.61
# 2             85.85                   81.71               82.90
# 3             88.46                   86.97               84.31
# 4             92.47                   92.40               85.90
#
#    Agriculture_Other_Food  Raw_Materials  Raw_Materials_Timber  \
# 0                   90.16          78.43                 92.15
# 1                   90.14          78.26                 92.24
# 2                   93.96          78.89                 92.12
# 3                   94.19          81.60                 93.21
# 4                   98.50          82.05                 94.45
#
#    Raw_Materials_Other  Fertilizers  Metals_Minerals  \
# 0                63.43        90.32            55.21
# 1                62.96        80.30            57.68
# 2                64.42        82.00            61.19
# 3                68.90        81.36            62.00
# 4                68.50        81.09            59.98
#
#    Metals_Minerals_Base_Metals  Precious_Metals
# 0                        61.37            84.73
# 1                        63.63            92.31
# 2                        66.46            95.59
# 3                        66.70            96.30
# 4                        65.14            98.12

# %%
prices_df.head()
# Out:
#      Month  Crude oil, average  Crude oil, Brent  Crude oil, Dubai  \
# 0  2016M01               29.78             30.80             27.00
# 1  2016M02               31.03             33.20             29.50
# 2  2016M03               37.34             39.07             35.18
# 3  2016M04               40.75             42.25             39.04
# 4  2016M05               45.94             47.13             43.95
#
#    Crude oil, WTI  Coal, Australian  Coal, South African **  Natural gas, US  \
# 0           31.54             49.02                   49.09             2.27
# 1           30.39             50.27                   50.33             1.96
# 2           37.77             52.21                   52.57             1.70
# 3           40.96             50.69                   52.35             1.90
# 4           46.73             51.31                   54.24             1.92
#
#    Natural gas, Europe **  Liquefied natural gas, Japan  ...  Aluminum  \
# 0                    4.40                          8.40  ...   1481.10
# 1                    3.97                          8.56  ...   1531.26
# 2                    3.91                          7.74  ...   1531.01
# 3                    3.97                          6.82  ...   1571.23
# 4                    4.33                          6.27  ...   1550.63
#
#    Iron ore, cfr spot   Copper     Lead       Tin   Nickel     Zinc     Gold  \
# 0               41.88  4471.79  1646.20  13808.08  8507.29  1520.36  1097.91
# 1               46.83  4598.62  1765.75  15610.14  8298.50  1709.85  1199.50
# 2               56.20  4953.80  1802.19  16897.60  8717.25  1801.69  1245.14
# 3               60.92  4872.74  1732.27  17032.71  8878.86  1855.37  1242.26
# 4               55.13  4694.54  1707.80  16706.95  8660.35  1869.03  1260.95
#
#    Platinum  Silver
# 0    855.25   14.11
# 1    919.35   15.17
# 2    967.73   15.47
# 3    994.19   16.36
# 4   1035.86   16.95
#
# [5 rows x 72 columns]

# %%
# look to compare clean_contracts.csv to clean_prices.csv
# combine data into a single dataset
natural_gas_data_df = pd.merge(energy_contracts_df, prices_df, how="left", on=["Month", "Month"])
pd.options.display.max_columns = None
natural_gas_data_df
# Out:
#        total_obligated_amount    Month    product_or_service_code_description  \
# 0                    10000.00  2016M09        GASES: COMPRESSED AND LIQUEFIED
# 1                     1384.98  2016M02   MINERAL CONSTRUCTION MATERIALS, BULK
# 2                   542491.46  2017M05  MAINTENANCE OF FUEL SUPPLY FACILITIES
# 3                    21764.63  2016M03   OTHER QC/TEST/INSPECT- MISCELLANEOUS
# 4                   256800.00  2020M12   MINERAL CONSTRUCTION MATERIALS, BULK
# ...                       ...      ...                                    ...
# 10575                  451.80  2018M09   MINERAL CONSTRUCTION MATERIALS, BULK
# 10576                99950.00  2021M05   MINERAL CONSTRUCTION MATERIALS, BULK
# 10577                29982.00  2021M08   MINERAL CONSTRUCTION MATERIALS, BULK
# 10578                  138.21  2016M12          NAILS, MACHINE KEYS, AND PINS
# 10579                  751.70  2018M01                BEVERAGES, NONALCOHOLIC
#
#                                        naics_description  \
# 0                          NATURAL GAS LIQUID EXTRACTION
# 1                    CONSTRUCTION SAND AND GRAVEL MINING
# 2          SUPPORT ACTIVITIES FOR OIL AND GAS OPERATIONS
# 3                    CONSTRUCTION SAND AND GRAVEL MINING
# 4      OTHER CRUSHED AND BROKEN STONE MINING AND QUAR...
# ...                                                  ...
# 10575  OTHER CRUSHED AND BROKEN STONE MINING AND QUAR...
# 10576                CONSTRUCTION SAND AND GRAVEL MINING
# 10577                              PHOSPHATE ROCK MINING
# 10578                 SUPPORT ACTIVITIES FOR COAL MINING
# 10579            POTASH, SODA, AND BORATE MINERAL MINING
#
#                                  recipient_name  \
# 0                        AMERIGAS PROPANE, L.P.
# 1                    BRAATEN SAND & GRAVEL, INC
# 2                        POND CONSTRUCTORS, INC
# 3                MISCELLANEOUS FOREIGN AWARDEES
# 4                FOREIGN AWARDEES (UNDISCLOSED)
# ...                                         ...
# 10575             GREEN DREAM INTERNATIONAL LLC
# 10576  HAT CREEK CONSTRUCTION & MATERIALS, INC.
# 10577                    DOUBLE A HAULING, INC.
# 10578           VIRGINIA ENERGY & LIGHTING, LLC
# 10579         ARMY & AIR FORCE EXCHANGE SERVICE
#
#               funding_sub_agency_name  Crude oil, average  Crude oil, Brent  \
# 0                    DEPT OF THE NAVY               45.04             46.19
# 1               FEDERAL PRISON SYSTEM               31.03             33.20
# 2            DEFENSE LOGISTICS AGENCY               49.89             50.87
# 3                STATE, DEPARTMENT OF               37.34             39.07
# 4                    DEPT OF THE ARMY               48.73             49.87
# ...                               ...                 ...               ...
# 10575                DEPT OF THE ARMY               75.36             78.86
# 10576                  FOREST SERVICE               66.40             68.04
# 10577  U.S. FISH AND WILDLIFE SERVICE               68.87             70.02
# 10578        DEFENSE LOGISTICS AGENCY               52.62             54.07
# 10579        DEFENSE LOGISTICS AGENCY               66.23             68.99
#
#        Crude oil, Dubai  Crude oil, WTI  Coal, Australian  \
# 0                 43.74           45.20             72.72
# 1                 29.50           30.39             50.27
# 2                 50.31           48.50             74.42
# 3                 35.18           37.77             52.21
# 4                 49.26           47.05             83.03
# ...                 ...             ...               ...
# 10575             77.02           70.21            114.16
# 10576             65.98           65.18            107.04
# 10577             68.85           67.73            169.58
# 10578             51.78           52.01             88.15
# 10579             66.02           63.67            106.45
#
#        Coal, South African **  Natural gas, US  Natural gas, Europe **  \
# 0                       68.33             2.97                    4.25
# 1                       50.33             1.96                    3.97
# 2                       74.41             3.12                    5.06
# 3                       52.57             1.70                    3.91
# 4                       85.18             2.54                    5.86
# ...                       ...              ...                     ...
# 10575                  102.14             2.98                    9.52
# 10576                   99.31             2.89                    8.91
# 10577                  137.92             4.05                   15.43
# 10578                   80.19             3.58                    5.42
# 10579                   97.48             3.86                    6.66
#
#        Liquefied natural gas, Japan  Natural gas index  Cocoa  \
# 0                              7.54              61.38   2.88
# 1                              8.56              48.43   2.92
# 2                              9.10              68.16   1.98
# 3                              7.74              44.49   3.07
# 4                              7.66              63.86   2.41
# ...                             ...                ...    ...
# 10575                         11.30              89.17   2.19
# 10576                          8.92              83.47   2.41
# 10577                         10.80             129.82   2.48
# 10578                          7.59              74.42   2.30
# 10579                          9.34              84.82   1.95
#
#        Coffee, Arabica  Coffee, Robusta  Tea, avg 3 auctions  Tea, Colombo  \
# 0                 3.89             2.14                 2.79          3.60
# 1                 3.26             1.63                 2.35          2.83
# 2                 3.31             2.17                 3.20          4.02
# 3                 3.47             1.67                 2.31          2.87
# 4                 3.48             1.59                 2.65          3.41
# ...                ...              ...                  ...           ...
# 10575             2.67             1.69                 2.67          3.25
# 10576             4.11             1.76                 2.71          3.08
# 10577             4.77             2.10                 2.72          2.99
# 10578             3.57             2.25                 2.98          3.91
# 10579             3.06             1.95                 3.10          4.16
#
#        Tea, Kolkata  Tea, Mombasa  Coconut oil  Groundnuts  Fish meal  \
# 0              2.44          2.33      1557.39     1550.00    1536.80
# 1              1.75          2.48      1218.93     1280.00    1511.99
# 2              2.63          2.94      1719.29     1593.04    1330.30
# 3              1.77          2.30      1440.48     1280.00    1443.58
# 4              2.60          1.94      1464.96     1937.50    1497.69
# ...             ...           ...          ...         ...        ...
# 10575          2.35          2.41       897.13     1380.00    1492.69
# 10576          3.14          1.92      1715.24     1450.00    1514.29
# 10577          3.00          2.16      1493.64     1443.18    1504.12
# 10578          2.36          2.67      1727.14     1600.00    1423.35
# 10579          2.19          2.96      1393.86     1180.22    1596.54
#
#        Groundnut oil  Palm oil  Palm kernel oil  Soybeans  Soybean oil  \
# 0            1433.00    797.85          1443.86    403.53       837.21
# 1            1317.26    679.17           986.90    373.75       767.24
# 2            1453.05    762.75          1098.57    389.72       825.06
# 3            1300.73    715.95          1210.60    380.97       765.61
# 4            1977.17   1016.37          1224.87    510.94      1026.20
# ...              ...       ...              ...       ...          ...
# 10575        1442.29    605.15           865.63    356.87       754.05
# 10576        2072.04   1136.46          1530.50    646.80      1574.67
# 10577        2102.29   1141.82          1341.14    585.80      1433.94
# 10578        1439.30    811.38          1666.43    416.07       916.70
# 10579        1433.00    703.45          1265.00    389.53       870.50
#
#        Soybean meal  Rapeseed oil  Sunflower oil  Barley   Maize  Sorghum  \
# 0            368.05        849.65         865.73   89.56  148.43   145.39
# 1            323.29        779.88         898.19  114.82  159.68   164.91
# 2            344.35        842.05         795.00   94.16  158.59   159.95
# 3            319.13        766.26         859.19  112.99  159.14   160.50
# 4            494.98       1097.63        1170.02     NaN  198.77      NaN
# ...             ...           ...            ...     ...     ...      ...
# 10575        377.15        821.47         733.95  119.42  154.80   163.58
# 10576        482.38       1531.38        1584.59     NaN  305.31      NaN
# 10577        470.26       1519.19        1355.69     NaN  256.61      NaN
# 10578        355.95        930.43         873.00   91.86  152.45   153.11
# 10579        375.74        848.38         799.04  121.71  155.84   178.46
#
#        Rice, Thai 5%   Rice, Thai 25%   Rice, Thai A.1  Rice, Viet Namese 5%  \
# 0               384.0              378          365.27                342.73
# 1               384.0              374          377.38                360.13
# 2               421.0              399          394.95                345.00
# 3               384.0              375          374.90                360.20
# 4               520.0              508          496.55                477.39
# ...               ...              ...             ...                   ...
# 10575           405.0              393          395.35                384.65
# 10576           493.0              483          462.75                477.70
# 10577           403.0              392          381.00                384.46
# 10578           373.0              364          354.42                341.00
# 10579           442.0              422          410.83                380.94
#
#        Wheat, US SRW  Wheat, US HRW  Banana, Europe  Banana, US  Orange  Beef  \
# 0             157.56         150.65            0.91        1.00    1.05  4.12
# 1             188.43         187.03            0.93        1.05    0.69  3.86
# 2             174.97         180.41            0.91        1.09    0.76  4.60
# 3             189.69         191.07            0.94        1.01    0.68  4.03
# 4             251.15         268.55            0.92        1.15    0.64  4.40
# ...              ...            ...             ...         ...     ...   ...
# 10575         202.05         212.38            0.89        1.11    0.80  4.01
# 10576         270.98         297.25            0.97        1.23    0.61  5.48
# 10577         276.18         324.52            0.89        1.23    0.72  5.61
# 10578         161.17         141.83            0.83        0.96    1.08  4.14
# 10579         178.34         192.17            0.98        1.13    0.76  4.30
#
#        Meat, chicken  Meat, sheep  Shrimps, Mexican  Sugar, EU  Sugar, US  \
# 0               1.70         4.83             11.88       0.37       0.62
# 1               1.77         4.51             10.80       0.36       0.56
# 2               2.33         5.40             14.29       0.36       0.63
# 3               1.85         4.48             10.67       0.36       0.58
# 4               1.81          NaN             11.68       0.40       0.63
# ...              ...          ...               ...        ...        ...
# 10575           2.03          NaN             11.53       0.38       0.56
# 10576           2.37          NaN             12.65       0.40       0.71
# 10577           2.38          NaN             15.76       0.38       0.76
# 10578           1.86         5.12             13.20       0.34       0.64
# 10579           2.07         5.60             12.36       0.40       0.59
#
#        Sugar, world  Tobacco, US import u.v.  Logs, Cameroon  Logs, Malaysian  \
# 0              0.47                  4957.02          392.42           292.15
# 1              0.29                  4670.33          388.43           259.34
# 2              0.35                  4582.06          386.75           265.28
# 3              0.34                  4569.68          388.89           263.62
# 4              0.31                  4200.40          425.85           286.86
# ...             ...                      ...             ...              ...
# 10575          0.25                  4973.96          408.07           265.85
# 10576          0.38                  4168.01          425.18           272.75
# 10577          0.43                  3973.24          412.02           271.03
# 10578          0.41                  4912.06          369.25           256.42
# 10579          0.31                  4649.44          426.69           268.30
#
#        Sawnwood, Cameroon  Sawnwood, Malaysian  Plywood  Cotton, A Index  \
# 0                  630.04               716.62   535.87             1.72
# 1                  685.86               780.11   475.70             1.47
# 2                  619.40               704.52   486.59             1.95
# 3                  681.40               775.04   483.53             1.44
# 4                  643.93               732.43   526.16             1.79
# ...                   ...                  ...      ...              ...
# 10575              625.49               711.44   487.63             1.99
# 10576              674.60               767.31   500.28             2.00
# 10577              661.23               752.10   497.13             2.23
# 10578              598.08               680.27   470.33             1.75
# 10579              661.09               751.94   492.12             2.01
#
#        Rubber, TSR20  Rubber, SGP/MYS  Phosphate rock     DAP     TSP   Urea   \
# 0               1.36             1.57          109.00  320.00  287.00  187.30
# 1               1.10             1.27          114.50  326.00  286.25  191.88
# 2               1.53             2.10           92.50  309.25  275.00  178.75
# 3               1.28             1.46          114.50  338.13  291.25  201.75
# 4               1.57             2.33           83.33  388.50  320.00  245.00
# ...              ...              ...             ...     ...     ...     ...
# 10575           1.33             1.44           87.50  421.63  376.25  267.50
# 10576           1.69             2.29          102.50  574.63  527.50  331.63
# 10577           1.71             1.90          136.88  603.13  555.00  446.88
# 10578           1.93             2.23           97.50  296.63  277.50  217.75
# 10579           1.50             1.72           80.00  360.38  320.00  219.63
#
#        Potassium chloride  Aluminum  Iron ore, cfr spot    Copper     Lead  \
# 0                   206.5   1592.36               57.79   4722.20  1947.64
# 1                   301.5   1531.26               46.83   4598.62  1765.75
# 2                   206.5   1913.02               62.43   5599.56  2125.11
# 3                   301.5   1531.01               56.20   4953.80  1802.19
# 4                   202.5   2014.67              155.43   7772.24  2020.47
# ...                   ...       ...                 ...       ...      ...
# 10575               215.5   2026.46               68.44   6050.76  2022.91
# 10576               202.5   2433.53              207.72  10161.97  2181.81
# 10577               221.0   2602.99              162.16   9370.14  2414.47
# 10578               206.5   1727.74               80.02   5660.35  2209.84
# 10579               215.5   2209.73               76.34   7065.85  2584.09
#
#             Tin    Nickel     Zinc     Gold  Platinum  Silver
# 0      19499.52  10191.78  2292.31  1326.61   1046.71   19.36
# 1      15610.14   8298.50  1709.85  1199.50    919.35   15.17
# 2      20200.33   9155.12  2590.21  1246.04    930.27   16.75
# 3      16897.60   8717.25  1801.69  1245.14    967.73   15.47
# 4      19731.96  16823.04  2779.85  1858.42   1028.00   24.97
# ...         ...       ...      ...      ...       ...     ...
# 10575  18967.13  12510.35  2434.68  1198.39    804.79   14.27
# 10576  32246.21  17577.06  2965.73  1850.26   1214.00   27.50
# 10577  35024.00  19141.30  2987.95  1785.28   1008.73   23.99
# 10578  21204.35  10972.27  2664.81  1157.36    918.38   16.43
# 10579  20696.91  12864.88  3441.52  1331.30    990.12   17.13
#
# [10580 rows x 77 columns]

# %%
# get column names from data set
print(natural_gas_data_df.columns)
# Out:
# Index(['total_obligated_amount', 'Month',
#        'product_or_service_code_description', 'naics_description',
#        'recipient_name', 'funding_sub_agency_name', 'Crude oil, average',
#        'Crude oil, Brent', 'Crude oil, Dubai', 'Crude oil, WTI',
#        'Coal, Australian', 'Coal, South African **', 'Natural gas, US',
#        'Natural gas, Europe **', 'Liquefied natural gas, Japan',
#        'Natural gas index', 'Cocoa', 'Coffee, Arabica', 'Coffee, Robusta',
#        'Tea, avg 3 auctions', 'Tea, Colombo', 'Tea, Kolkata', 'Tea, Mombasa',
#        'Coconut oil', 'Groundnuts', 'Fish meal', 'Groundnut oil', 'Palm oil',
#        'Palm kernel oil', 'Soybeans', 'Soybean oil', 'Soybean meal',
#        'Rapeseed oil', 'Sunflower oil', 'Barley', 'Maize', 'Sorghum',
#        'Rice, Thai 5% ', 'Rice, Thai 25% ', 'Rice, Thai A.1',
#        'Rice, Viet Namese 5%', 'Wheat, US SRW', 'Wheat, US HRW',
#        'Banana, Europe', 'Banana, US', 'Orange', 'Beef', 'Meat, chicken',
#        'Meat, sheep', 'Shrimps, Mexican', 'Sugar, EU', 'Sugar, US',
#        'Sugar, world', 'Tobacco, US import u.v.', 'Logs, Cameroon',
#        'Logs, Malaysian', 'Sawnwood, Cameroon', 'Sawnwood, Malaysian',
#        'Plywood', 'Cotton, A Index', 'Rubber, TSR20', 'Rubber, SGP/MYS',
#        'Phosphate rock', 'DAP', 'TSP', 'Urea ', 'Potassium chloride',
#        'Aluminum', 'Iron ore, cfr spot', 'Copper', 'Lead', 'Tin', 'Nickel',
#        'Zinc', 'Gold', 'Platinum', 'Silver'],
#       dtype='object')

# %%
# make summary DataFrame to reduce columns
# columns ["Natural gas, US", ]
natural_gas_data_summary_df = pd.DataFrame({})

# naics stands for North American Industry Classification System

# keep specific columns
natural_gas_data_df1 = natural_gas_data_df[['Month','naics_description','product_or_service_code_description','total_obligated_amount','recipient_name','funding_sub_agency_name','Natural gas, US']]
natural_gas_data_df1
# Out:
#          Month                                  naics_description  \
# 0      2016M09                      NATURAL GAS LIQUID EXTRACTION
# 1      2016M02                CONSTRUCTION SAND AND GRAVEL MINING
# 2      2017M05      SUPPORT ACTIVITIES FOR OIL AND GAS OPERATIONS
# 3      2016M03                CONSTRUCTION SAND AND GRAVEL MINING
# 4      2020M12  OTHER CRUSHED AND BROKEN STONE MINING AND QUAR...
# ...        ...                                                ...
# 10575  2018M09  OTHER CRUSHED AND BROKEN STONE MINING AND QUAR...
# 10576  2021M05                CONSTRUCTION SAND AND GRAVEL MINING
# 10577  2021M08                              PHOSPHATE ROCK MINING
# 10578  2016M12                 SUPPORT ACTIVITIES FOR COAL MINING
# 10579  2018M01            POTASH, SODA, AND BORATE MINERAL MINING
#
#          product_or_service_code_description  total_obligated_amount  \
# 0            GASES: COMPRESSED AND LIQUEFIED                10000.00
# 1       MINERAL CONSTRUCTION MATERIALS, BULK                 1384.98
# 2      MAINTENANCE OF FUEL SUPPLY FACILITIES               542491.46
# 3       OTHER QC/TEST/INSPECT- MISCELLANEOUS                21764.63
# 4       MINERAL CONSTRUCTION MATERIALS, BULK               256800.00
# ...                                      ...                     ...
# 10575   MINERAL CONSTRUCTION MATERIALS, BULK                  451.80
# 10576   MINERAL CONSTRUCTION MATERIALS, BULK                99950.00
# 10577   MINERAL CONSTRUCTION MATERIALS, BULK                29982.00
# 10578          NAILS, MACHINE KEYS, AND PINS                  138.21
# 10579                BEVERAGES, NONALCOHOLIC                  751.70
#
#                                  recipient_name  \
# 0                        AMERIGAS PROPANE, L.P.
# 1                    BRAATEN SAND & GRAVEL, INC
# 2                        POND CONSTRUCTORS, INC
# 3                MISCELLANEOUS FOREIGN AWARDEES
# 4                FOREIGN AWARDEES (UNDISCLOSED)
# ...                                         ...
# 10575             GREEN DREAM INTERNATIONAL LLC
# 10576  HAT CREEK CONSTRUCTION & MATERIALS, INC.
# 10577                    DOUBLE A HAULING, INC.
# 10578           VIRGINIA ENERGY & LIGHTING, LLC
# 10579         ARMY & AIR FORCE EXCHANGE SERVICE
#
#               funding_sub_agency_name  Natural gas, US
# 0                    DEPT OF THE NAVY             2.97
# 1               FEDERAL PRISON SYSTEM             1.96
# 2            DEFENSE LOGISTICS AGENCY             3.12
# 3                STATE, DEPARTMENT OF             1.70
# 4                    DEPT OF THE ARMY             2.54
# ...                               ...              ...
# 10575                DEPT OF THE ARMY             2.98
# 10576                  FOREST SERVICE             2.89
# 10577  U.S. FISH AND WILDLIFE SERVICE             4.05
# 10578        DEFENSE LOGISTICS AGENCY             3.58
# 10579        DEFENSE LOGISTICS AGENCY             3.86
#
# [10580 rows x 7 columns]

# %%
# unique values from naics_description column
print(pd.unique(natural_gas_data_df1['naics_description']))
# Out:
# ['NATURAL GAS LIQUID EXTRACTION' 'CONSTRUCTION SAND AND GRAVEL MINING'
#  'SUPPORT ACTIVITIES FOR OIL AND GAS OPERATIONS'
#  'OTHER CRUSHED AND BROKEN STONE MINING AND QUARRYING'
#  'SUPPORT ACTIVITIES FOR COAL MINING'
#  'CRUDE PETROLEUM AND NATURAL GAS EXTRACTION'
#  'CRUSHED AND BROKEN LIMESTONE MINING AND QUARRYING'
#  'NATURAL GAS EXTRACTION'
#  'SUPPORT ACTIVITIES FOR NONMETALLIC MINERALS (EXCEPT FUELS)'
#  'OTHER CHEMICAL AND FERTILIZER MINERAL MINING'
#  'POTASH, SODA, AND BORATE MINERAL MINING'
#  'COPPER ORE AND NICKEL ORE MINING'
#  'CRUSHED AND BROKEN GRANITE MINING AND QUARRYING'
#  'ALL OTHER NONMETALLIC MINERAL MINING'
#  'DIMENSION STONE MINING AND QUARRYING' 'ALL OTHER METAL ORE MINING'
#  'BITUMINOUS COAL UNDERGROUND MINING' 'PHOSPHATE ROCK MINING'
#  'DRILLING OIL AND GAS WELLS' 'GOLD ORE MINING'
#  'CRUDE PETROLEUM EXTRACTION' 'INDUSTRIAL SAND MINING'
#  'SUPPORT ACTIVITIES FOR METAL MINING'
#  'BITUMINOUS COAL AND LIGNITE SURFACE MINING'
#  'CLAY AND CERAMIC AND REFRACTORY MINERALS MINING'
#  'KAOLIN AND BALL CLAY MINING' 'COPPER, NICKEL, LEAD, AND ZINC MINING'
#  'IRON ORE MINING']

# %%
# Relevant NAICS descriptions
# 'CRUDE PETROLEUM AND NATURAL GAS EXTRACTION' 'NATURAL GAS LIQUID EXTRACTION' 'SUPPORT ACTIVITIES FOR OIL AND GAS OPERATIONS' 'NATURAL GAS EXTRACTION'

# %%
print(natural_gas_data_df1.columns)
# Out:
# Index(['Month', 'naics_description', 'product_or_service_code_description',
#        'total_obligated_amount', 'recipient_name', 'funding_sub_agency_name',
#        'Natural gas, US'],
#       dtype='object')

# %%
extract_values = ['CRUDE PETROLEUM AND NATURAL GAS EXTRACTION', 'NATURAL GAS LIQUID EXTRACTION', 'SUPPORT ACTIVITIES FOR OIL AND GAS OPERATIONS', 'NATURAL GAS EXTRACTION']

# %%
natural_gas_data_df2=natural_gas_data_df1.loc[natural_gas_data_df1['naics_description'].isin(extract_values)]

# %%
natural_gas_data_df2['mm'] = natural_gas_data_df2['Month']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
natural_gas_data_df2.columns
# Out:
# Index(['Month', 'naics_description', 'product_or_service_code_description',
#        'total_obligated_amount', 'recipient_name', 'funding_sub_agency_name',
#        'Natural gas, US', 'mm'],
#       dtype='object')

# %%
natural_gas_data_df2['yyyy'] = natural_gas_data_df2['Month'].str.split(pat='M').str[0]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
natural_gas_data_df2['mm'] = natural_gas_data_df2['Month'].str.split(pat='M').str[1]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# Create CSV in ResourcesUCB folder
natural_gas_data_df2.to_csv('natural_gas_data_df2.csv')

# %%
# unique values from product_or_service_code_description
print(pd.unique(natural_gas_data_df1['product_or_service_code_description']))
# Out:
# ['GASES: COMPRESSED AND LIQUEFIED' 'MINERAL CONSTRUCTION MATERIALS, BULK'
#  'MAINTENANCE OF FUEL SUPPLY FACILITIES'
#  'OTHER QC/TEST/INSPECT- MISCELLANEOUS'
#  'MISCELLANEOUS ELECTRICAL AND ELECTRONIC COMPONENTS'
#  'MISCELLANEOUS CONSTRUCTION MATERIALS'
#  'MISCELLANEOUS CONSTRUCTION EQUIPMENT'
#  'BEARINGS, ANTIFRICTION, UNMOUNTED' 'NAILS, MACHINE KEYS, AND PINS'
#  'CONSTRUCTION OF MISCELLANEOUS BUILDINGS' 'FUEL OILS'
#  'HARDWARE, COMMERCIAL' 'BEARINGS, PLAIN, UNMOUNTED'
#  'BUILDING COMPONENTS, PREFABRICATED' 'R&D- ENERGY: GAS (BASIC RESEARCH)'
#  'ELECTRICAL HARDWARE AND SUPPLIES'
#  'LIQUID PROPELLANTS AND FUELS, PETROLEUM BASE' 'UTILITIES- GAS'
#  'SUPPORT- PROFESSIONAL: ENGINEERING/TECHNICAL'
#  'ENVIRONMENTAL SYSTEMS PROTECTION- MULTIPLE POLLUTANT SUPPORT'
#  'GASOLINE ROTARY ENGINES AND COMPONENTS'
#  'HOUSEKEEPING- SNOW REMOVAL/SALT' 'NUTS AND WASHERS'
#  'CONSTRUCTION OF MAINTENANCE BUILDINGS' 'COFFEE, TEA, AND COCOA'
#  'NATURAL RESOURCES/CONSERVATION- SURFACE MINING RECLAMATION (NON-CONSTRUCTION)'
#  'AIR CONDITIONING EQUIPMENT' 'PACKING AND GASKET MATERIALS'
#  'MISCELLANEOUS POWER TRANSMISSION EQUIPMENT'
#  'MISCELLANEOUS SERVICE AND TRADE EQUIPMENT'
#  'INFORMATION TECHNOLOGY SOFTWARE' 'BEVERAGES, NONALCOHOLIC'
#  'UTILITIES- ELECTRIC' 'MINERALS, NATURAL AND SYNTHETIC'
#  'CONSTRUCTION OF PARKING FACILITIES'
#  'OTHER QC/TEST/INSPECT- SHIP AND MARINE EQUIPMENT'
#  'REPAIR OR ALTERATION OF OTHER NON-BUILDING FACILITIES'
#  'SPECIAL STUDIES/ANALYSIS- SOIL' 'O-RING'
#  'ARCHITECT AND ENGINEERING- CONSTRUCTION: MISCELLANEOUS BUILDINGS'
#  'FENCING, FENCES, GATES AND COMPONENTS' 'ORES'
#  'EARTH MOVING AND EXCAVATING EQUIPMENT' 'MARINE HARDWARE AND HULL ITEMS'
#  'MINING, ROCK DRILLING, EARTH BORING, AND RELATED EQUIPMENT'
#  'NATURAL RESOURCES/CONSERVATION- WELL DRILLING/EXPLORATORY'
#  'MAINTENANCE OF FAMILY HOUSING FACILITIES'
#  'CLAY AND CONCRETE PRODUCTS INDUSTRIES MACHINERY'
#  'CONSTRUCTION OF OTHER NON-BUILDING FACILITIES'
#  'MISCELLANEOUS CHEMICAL SPECIALTIES'
#  'REPAIR OR ALTERATION OF HIGHWAYS/ROADS/STREETS/BRIDGES/RAILWAYS'
#  'SCAFFOLDING EQUIPMENT AND CONCRETE FORMS' 'CHEMICALS'
#  'ARCHITECT AND ENGINEERING- CONSTRUCTION: MAINTENANCE BUILDINGS'
#  'MAPS, ATLASES, CHARTS, AND GLOBES'
#  'CONSTRUCTION OF FAMILY HOUSING FACILITIES'
#  'FOUNDRY MACHINERY, RELATED EQUIPMENT AND SUPPLIES'
#  'MAINT/REPAIR/REBUILD OF EQUIPMENT- INSTRUMENTS AND LABORATORY EQUIPMENT'
#  'CONSTRUCTION OF OFFICE BUILDINGS' 'MISCELLANEOUS OFFICE MACHINES'
#  'TRUCKS AND TRUCK TRACTORS, WHEELED'
#  'REPAIR OR ALTERATION OF FAMILY HOUSING FACILITIES'
#  'REPAIR OR ALTERATION OF CONFERENCE SPACE AND FACILITIES' 'FUELS, SOLID'
#  'MAINT/REPAIR/REBUILD OF EQUIPMENT- FUELS, LUBRICANTS, OILS, AND WAXES'
#  'LEASE OR RENTAL OF EQUIPMENT- MISCELLANEOUS'
#  'MAINT/REPAIR/REBUILD OF EQUIP- FIRE FIGHTING/RESCUE/SAFETY EQUIP; ENVIRON PROTECT EQUIP/MATLS'
#  'MISCELLANEOUS AIRCRAFT ACCESSORIES AND COMPONENTS'
#  'CONSTRUCTION OF MISSILE SYSTEM FACILITIES' 'SOIL PREPARATION EQUIPMENT'
#  'REPAIR OR ALTERATION OF FUEL SUPPLY FACILITIES' 'HOUSEKEEPING- OTHER'
#  'MEDICAL AND SURGICAL INSTRUMENTS, EQUIPMENT, AND SUPPLIES'
#  'VEHICULAR POWER TRANSMISSION COMPONENTS'
#  'MISCELLANEOUS PREFABRICATED STRUCTURES'
#  'BUSHINGS, RINGS, SHIMS, AND SPACERS'
#  'TRANSPORTATION/TRAVEL/RELOCATION- TRANSPORTATION: MOTOR FREIGHT'
#  'CONSTRUCTION OF DAMS' 'CONSTRUCTION OF OPEN STORAGE FACILITIES'
#  'SUPPORT- PROFESSIONAL: PERSONAL SERVICES CONTRACTS'
#  'MAINTENANCE OF OTHER RESIDENTIAL BUILDINGS'
#  'CONSTRUCTION OF AMMUNITION FACILITIES'
#  'MAINTENANCE OF OTHER CONSERVATION AND DEVELOPMENT FACILITIES'
#  'NATURAL RESOURCES/CONSERVATION- OTHER'
#  'VIDEO RECORDING AND REPRODUCING EQUIPMENT'
#  'ARCHITECT AND ENGINEERING- CONSTRUCTION: AIRPORT SERVICE ROADS'
#  'ARCHITECT AND ENGINEERING- CONSTRUCTION: CONFERENCE SPACE AND FACILITIES'
#  'MAINTENANCE OF OTHER WAREHOUSE BUILDINGS'
#  'SPECIAL STUDIES/ANALYSIS- SCIENTIFIC DATA'
#  'MAINTENANCE OF HIGHWAYS/ROADS/STREETS/BRIDGES/RAILWAYS'
#  'ARCHITECT AND ENGINEERING- CONSTRUCTION: OFFICE BUILDINGS'
#  'CONSTRUCTION OF OTHER INDUSTRIAL BUILDINGS'
#  'ROOFING AND SIDING MATERIALS'
#  'EQUIPMENT AND MATERIALS TESTING- MISCELLANEOUS'
#  'HOSE AND FLEXIBLE TUBING' 'KNOBS AND POINTERS' 'GEOPHYSICAL INSTRUMENTS'
#  'SUPPORT- PROFESSIONAL: OTHER' 'CONSTRUCTION OF RECREATIONAL BUILDINGS'
#  'OTHER QC/TEST/INSPECT- WATER PURIFICATION AND SEWAGE TREATMENT EQUIPMENT'
#  'ARCHITECT AND ENGINEERING- CONSTRUCTION: FAMILY HOUSING FACILITIES'
#  'CONSTRUCTION OF OTHER RESIDENTIAL BUILDINGS' 'STORAGE TANKS'
#  'INFORMATION TECHNOLOGY INPUT/OUTPUT AND STORAGE DEVICES'
#  'MAINTENANCE OF OTHER UTILITIES' 'WATER PURIFICATION EQUIPMENT'
#  'CONSTRUCTION OF AMMUNITION STORAGE BUILDINGS'
#  'IRON AND STEEL PRIMARY AND SEMIFINISHED PRODUCTS'
#  'HARDWARE, WEAPON SYSTEM' 'HOUSEKEEPING- FUELING AND OTHER PETROLEUM'
#  'POWER AND HAND PUMPS'
#  'LIQUID AND GAS FLOW, LIQUID LEVEL, AND MECHANICAL MOTION MEASURING INSTRUMENTS'
#  'CONSTRUCTION OF OTHER ADMINISTRATIVE FACILITIES AND SERVICE BUILDINGS'
#  'OPERATION OF HIGHWAYS, ROADS, STREETS, BRIDGES, AND RAILWAYS'
#  'OILS AND GREASES: CUTTING, LUBRICATING, AND HYDRAULIC'
#  'MAINT/REPAIR/REBUILD OF EQUIPMENT- SHIPS, SMALL CRAFT, PONTOONS, AND FLOATING DOCKS'
#  'HOUSEKEEPING- FACILITIES OPERATIONS SUPPORT'
#  'MISCELLANEOUS VEHICULAR COMPONENTS'
#  'QUALITY CONTROL- FUELS, LUBRICANTS, OILS, AND WAXES'
#  'MAINT/REPAIR/REBUILD OF EQUIPMENT- MISCELLANEOUS'
#  'WALLBOARD, BUILDING PAPER, AND THERMAL INSULATION MATERIALS'
#  'CONSTRUCTION OF OTHER UTILITIES'
#  'ARCHITECT AND ENGINEERING- CONSTRUCTION: OTHER RESIDENTIAL BUILDINGS'
#  'FERTILIZERS' 'MARINE LIFESAVING AND DIVING EQUIPMENT'
#  'PAINTS, DOPES, VARNISHES, AND RELATED PRODUCTS'
#  'INSTALLATION OF EQUIPMENT- CONSTRUCTION AND BUILDING MATERIALS'
#  'MISCELLANEOUS ENGINES AND COMPONENTS' 'AMMUNITION, OVER 125MM'
#  'ARCHITECT AND ENGINEERING- GENERAL: ELECTRICAL SYSTEMS'
#  'EQUIPMENT AND MATERIALS TESTING- MAINTENANCE AND REPAIR SHOP EQUIPMENT'
#  'MAINT/REPAIR/REBUILD OF EQUIPMENT- MEDICAL, DENTAL, AND VETERINARY EQUIPMENT AND SUPPLIES'
#  'INFORMATION TECHNOLOGY SUPPLIES'
#  'LEASE OR RENTAL OF EQUIPMENT- SPECIAL INDUSTRY MACHINERY'
#  'SPECIAL STUDIES/ANALYSIS- GEOLOGICAL'
#  'CONSTRUCTION OF ELECTRONIC AND COMMUNICATIONS FACILITIES'
#  'MAINTENANCE OF MISCELLANEOUS BUILDINGS'
#  'MAINTENANCE OF MAINTENANCE BUILDINGS'
#  'TECHNICAL REPRESENTATIVE- REFRIGERATION, AIR CONDITIONING, AND AIR CIRCULATING EQUIPMENT'
#  'REPAIR OR ALTERATION OF OTHER ADMINISTRATIVE FACILITIES AND SERVICE BUILDINGS'
#  'DISKS AND STONES, ABRASIVE'
#  'R&D- MINING: OTHER MINING ACTIVITIES (OPERATIONAL SYSTEMS DEVELOPMENT)'
#  'MISCELLANEOUS CRUDE ANIMAL PRODUCTS, INEDIBLE'
#  'REPAIR OR ALTERATION OF PARKING FACILITIES'
#  'SUPPORT- MANAGEMENT: LOGISTICS SUPPORT'
#  'SPACE AND WATER HEATING EQUIPMENT'
#  'MISCELLANEOUS SHIP AND MARINE EQUIPMENT'
#  'TRANSPORTATION/TRAVEL/RELOCATION- TRANSPORTATION: OTHER'
#  'PRESERVATIVE AND SEALING COMPOUNDS'
#  'SUPPORT- PROFESSIONAL: EXPERT WITNESS'
#  'REPAIR OR ALTERATION OF MISCELLANEOUS BUILDINGS' 'ABRASIVE MATERIALS'
#  'INSPECTION- MISCELLANEOUS' 'MATERIALS FEEDERS' 'UTILITIES- OTHER'
#  'CONSTRUCTION OF OTHER CONSERVATION AND DEVELOPMENT FACILITIES'
#  'SEEDS AND NURSERY STOCK'
#  'SUPPORT- PROFESSIONAL: PROGRAM EVALUATION/REVIEW/DEVELOPMENT'
#  'QUALITY CONTROL- MISCELLANEOUS'
#  'MAINT/REPAIR/REBUILD OF EQUIPMENT- CONSTRUCTION AND BUILDING MATERIALS'
#  'ARCHITECT AND ENGINEERING- CONSTRUCTION: OTHER UTILITIES'
#  'LUMBER AND RELATED BASIC WOOD MATERIALS'
#  'ENVIRONMENTAL SYSTEMS PROTECTION- LEAKING UNDERGROUND STORAGE TANK SUPPORT'
#  'NEWSPAPERS AND PERIODICALS'
#  'ENERGY R&D SERVICES; EMERGENCY ENERGY PREPAREDNESS; BASIC RESEARCH'
#  'EQUIPMENT AND MATERIALS TESTING- CHEMICALS AND CHEMICAL PRODUCTS'
#  'REPAIR OR ALTERATION OF EXHIBIT DESIGN (NON-BUILDING)'
#  'ENVIRONMENTAL SYSTEMS PROTECTION- OIL SPILL RESPONSE'
#  'OTHER QC/TEST/INSPECT- LUMBER, MILLWORK, PLYWOOD, AND VENEER'
#  'ENVIRONMENTAL SYSTEMS PROTECTION- WATER QUALITY SUPPORT'
#  'MAINT/REPAIR/REBUILD OF EQUIPMENT- CONSTRUCTION/MINING/EXCAVATING/HIGHWAY MAINTENANCE EQUIPMENT'
#  'MAINTENANCE OF WATER SUPPLY FACILITIES'
#  'CONSTRUCTION OF GOVERNMENT-OWNED CONTRACTOR-OPERATED (GOCO) R&D FACILITIES'
#  'INSPECTION- MAINTENANCE AND REPAIR SHOP EQUIPMENT'
#  'OTHER QC/TEST/INSPECT- FUELS, LUBRICANTS, OILS, AND WAXES'
#  'TILE, BRICK AND BLOCK' 'OTHER ENVIRONMENTAL SERVICES'
#  'SUPPORT- PROFESSIONAL: MARKET RESEARCH/PUBLIC OPINION'
#  'TOOL AND HARDWARE BOXES'
#  'INSTALLATION OF EQUIPMENT- ADP EQUIPMENT/SOFTWARE/SUPPLIES/SUPPORT EQUIPMENT'
#  'PURCHASE OF HIGHWAYS, ROADS, STREETS, BRIDGES, AND RAILWAYS'
#  'MAINTENANCE OF OTHER ADMINISTRATIVE FACILITIES AND SERVICE BUILDINGS'
#  'R&D- GENERAL SCIENCE/TECHNOLOGY: OTHER (ADVANCED DEVELOPMENT)'
#  'MODIFICATION OF EQUIPMENT- HAND TOOLS'
#  'CONSTRUCTION OF EPG FACILITIES - OTHER, INCLUDING TRANSMISSION'
#  'ENVIRONMENTAL SYSTEMS PROTECTION- ENVIRONMENTAL REMEDIATION'
#  'MODIFICATION OF EQUIPMENT- MISCELLANEOUS'
#  'CHEMICAL ANALYSIS INSTRUMENTS'
#  'REPAIR OR ALTERATION OF UNIMPROVED REAL PROPERTY (LAND)'
#  'MODIFICATION OF EQUIPMENT- CONSTRUCTION AND BUILDING MATERIALS'
#  'SUPPORT- MANAGEMENT: OTHER' 'RIVETS'
#  'INSPECTION- PIPE, TUBING, HOSE, AND FITTINGS'
#  'COMPRESSORS AND VACUUM PUMPS'
#  'ARCHITECT AND ENGINEERING- GENERAL: OTHER'
#  'SUPPORT- PROFESSIONAL: OPERATIONS RESEARCH/QUANTITATIVE ANALYSIS'
#  'CONSTRUCTION OF UNIMPROVED REAL PROPERTY (LAND)'
#  'MAINTENANCE OF FUEL STORAGE BUILDINGS'
#  'AIRCRAFT GUNNERY FIRE CONTROL COMPONENTS'
#  'ARCHITECT AND ENGINEERING- GENERAL: INSPECTION (NON-CONSTRUCTION)'
#  'SPECIAL STUDIES/ANALYSIS- GEOPHYSICAL'
#  'FOOD PRODUCTS MACHINERY AND EQUIPMENT'
#  'REPAIR OR ALTERATION OF RESTORATION OF REAL PROPERTY (PUBLIC OR PRIVATE)'
#  'EQUIPMENT AND MATERIALS TESTING- FUELS, LUBRICANTS, OILS, AND WAXES'
#  'SOUND RECORDING AND REPRODUCING EQUIPMENT'
#  'INSTALLATION OF EQUIPMENT- ALARM, SIGNAL, AND SECURITY DETECTION SYSTEMS'
#  'DIGITAL MAPS, CHARTS AND GEODETIC PRODUCTS'
#  'NATURAL RESOURCES/CONSERVATION- SITE PREPARATION'
#  'RUBBER FABRICATED MATERIALS' 'IT AND TELECOM- WEB-BASED SUBSCRIPTION'
#  'LEASE OR RENTAL OF EQUIPMENT- GROUND EFFECT VEHICLES, MOTOR VEHICLES, TRAILERS, AND CYCLES'
#  'MOTOR VEHICLE MAINTENANCE AND REPAIR SHOP SPECIALIZED EQUIPMENT'
#  'CONSTRUCTION OF EPG FACILITIES - GAS'
#  'SPECIAL STUDIES/ANALYSIS- REGULATORY'
#  'NATURAL RESOURCES/CONSERVATION- OTHER FOREST/RANGE IMPROVEMENTS (NON-CONSTRUCTION)'
#  'CONSTRUCTION OF CONFERENCE SPACE AND FACILITIES'
#  'MISCELLANEOUS ALARM, SIGNAL, AND SECURITY DETECTION SYSTEMS'
#  'MISCELLANEOUS FABRICATED NONMETALLIC MATERIALS'
#  'OPERATION OF FUEL STORAGE BUILDINGS'
#  'ENGINE AIR AND OIL FILTERS, STRAINERS, AND CLEANERS, NONAIRCRAFT'
#  'HELICOPTER ROTOR BLADES, DRIVE MECHANISMS AND COMPONENTS'
#  'INSTALLATION OF EQUIPMENT- ELECTRIC WIRE AND POWER DISTRIBUTION EQUIPMENT'
#  'PRINTING, DUPLICATING, AND BOOKBINDING EQUIPMENT'
#  'MAINT/REPAIR/REBUILD OF EQUIPMENT- MAINTENANCE AND REPAIR SHOP EQUIPMENT'
#  'EQUIPMENT AND MATERIALS TESTING- PIPE, TUBING, HOSE, AND FITTINGS'
#  'NONWOOD CONSTRUCTION LUMBER AND RELATED MATERIALS'
#  'TRANSPORTATION/TRAVEL/RELOCATION- OTHER: OTHER'
#  'VEHICULAR BRAKE, STEERING, AXLE, WHEEL, AND TRACK COMPONENTS'
#  'BATTERIES, NONRECHARGEABLE' 'OFFICE SUPPLIES'
#  'REPAIR OR ALTERATION OF CANALS'
#  'SPECIAL STUDIES/ANALYSIS- ENVIRONMENTAL ASSESSMENTS'
#  'SPECIAL STUDIES/ANALYSIS- MEDICAL/HEALTH'
#  'LEASE OR RENTAL OF EQUIPMENT- FIRE CONTROL EQUIPMENT'
#  'CLEANING AND POLISHING COMPOUNDS AND PREPARATIONS'
#  'AIRCRAFT AIR CONDITIONING, HEATING, AND PRESSURIZING EQUIPMENT'
#  'SURGICAL DRESSING MATERIALS'
#  'MAINT/REPAIR/REBUILD OF EQUIPMENT- PLUMBING, HEATING, AND WASTE DISPOSAL EQUIPMENT'
#  'PREFABRICATED TOWER STRUCTURES'
#  'OPERATION OF OTHER NON-BUILDING FACILITIES'
#  'MAINTENANCE OF PARKING FACILITIES' 'DRILLING AND TAPPING MACHINES'
#  'OPERATION TRAINING DEVICES'
#  'CONSTRUCTION OF RECREATION FACILITIES (NON-BUILDING)'
#  'MATERIAL HANDLING EQUIPMENT, NONSELF-PROPELLED'
#  'R&D- GENERAL SCIENCE/TECHNOLOGY: OTHER (ENGINEERING DEVELOPMENT)'
#  'INSPECTION- SERVICE AND TRADE EQUIPMENT' 'CONSTRUCTION OF CANALS'
#  'MAINT/REPAIR/REBUILD OF EQUIPMENT- BRUSHES, PAINTS, SEALERS, AND ADHESIVES'
#  'CONSTRUCTION OF WATER SUPPLY FACILITIES'
#  'MAINTENANCE OF AMMUNITION FACILITIES'
#  'HOUSEKEEPING- LANDSCAPING/GROUNDSKEEPING'
#  'MODIFICATION OF EQUIPMENT- SHIP AND MARINE EQUIPMENT'
#  'MAINT/REPAIR/REBUILD OF EQUIPMENT- ELECTRICAL AND ELECTRONIC EQUIPMENT COMPONENTS'
#  'CONSTRUCTION OF OTHER WAREHOUSE BUILDINGS'
#  'R&D- DEFENSE SYSTEM: ELECTRONICS/COMMUNICATION EQUIPMENT (ADVANCED DEVELOPMENT)'
#  'ARCHITECT AND ENGINEERING- CONSTRUCTION: OTHER ADMINISTRATIVE FACILITIES/SERVICE BUILDINGS'
#  'MAINTENANCE OF DAMS'
#  'ARCHITECT AND ENGINEERING- CONSTRUCTION: OTHER NON-BUILDING FACILITIES'
#  'ADDITIVE METAL MATERIALS' 'PURCHASE OF FUEL SUPPLY FACILITIES'
#  'INSPECTION- CONSTRUCTION AND BUILDING MATERIALS'
#  'LEASE OR RENTAL OF EQUIPMENT- CONSTRUCTION, MINING, EXCAVATING, AND HIGHWAY MAINTENANCE EQUIPMENT'
#  'SALVAGE- OTHER' 'RECREATIONAL AND GYMNASTIC EQUIPMENT'
#  'TECHNICAL REPRESENTATIVE- WATER PURIFICATION AND SEWAGE TREATMENT EQUIPMENT'
#  'TRAILERS' 'CONSTRUCTION OF SEWAGE AND WASTE FACILITIES'
#  'ENERGY R&D SERVICES; ENERGY SUPPLY; BASIC RESEARCH'
#  'PLATE, SHEET, STRIP, AND FOIL; NONFERROUS BASE METAL'
#  'MAINTENANCE OF RESTORATION OF REAL PROPERTY (PUBLIC OR PRIVATE)'
#  'SUGAR, CONFECTIONERY, AND NUTS'
#  'ARCHITECT AND ENGINEERING- CONSTRUCTION: FUEL SUPPLY FACILITIES'
#  'SPECIAL STUDIES/ANALYSIS- OTHER' 'FORAGE AND FEED'
#  'AIRCRAFT GROUND SERVICING EQUIPMENT'
#  'CONSTRUCTION OF TUNNELS AND SUBSURFACE STRUCTURES'
#  'HOUSEKEEPING- TRASH/GARBAGE COLLECTION'
#  'REPAIR OR ALTERATION OF WATER SUPPLY FACILITIES'
#  'CONSTRUCTION OF HIGHWAYS, ROADS, STREETS, BRIDGES, AND RAILWAYS'
#  'QUALITY CONTROL- CONSTRUCTION AND BUILDING MATERIALS'
#  'MISCELLANEOUS MAINTENANCE AND REPAIR SHOP SPECIALIZED EQUIPMENT'
#  'LEASE OR RENTAL OF EQUIPMENT- FUELS, LUBRICANTS, OILS, AND WAXES'
#  'SCREWS' 'GAMES, TOYS, AND WHEELED GOODS'
#  'INSTALLATION OF EQUIPMENT- ELECTRICAL AND ELECTRONIC EQUIPMENT COMPONENTS'
#  'CONSTRUCTION OF AIRPORT SERVICE ROADS'
#  'MAINT/REPAIR/REBUILD OF EQUIPMENT- CLEANING EQUIPMENT AND SUPPLIES'
#  'WASTE DISPOSAL EQUIPMENT'
#  'CONSTRUCTION OF RESTORATION OF REAL PROPERTY (PUBLIC OR PRIVATE)'
#  'MAINT/REPAIR/REBUILD OF EQUIPMENT- FURNACE, STEAM PLANT, AND DRYING EQUIPMENT; NUCLEAR REACTORS'
#  'INSTALLATION OF EQUIPMENT- MISCELLANEOUS'
#  'INSTALLATION OF EQUIPMENT- PLUMBING, HEATING, AND WASTE DISPOSAL EQUIPMENT'
#  'KITCHEN EQUIPMENT AND APPLIANCES'
#  'MAINTENANCE OF LABORATORIES AND CLINICS'
#  'LABORATORY EQUIPMENT AND SUPPLIES'
#  'PURCHASE OF OTHER NON-BUILDING FACILITIES'
#  'NATURAL RESOURCES/CONSERVATION- TREE THINNING'
#  'GASOLINE RECIPROCATING ENGINES, EXCEPT AIRCRAFT; AND COMPONENTS'
#  'SUPPORT- PROFESSIONAL: PROGRAM MANAGEMENT/SUPPORT'
#  'MAINTENANCE OF CANALS'
#  'INSPECTION- FIRE FIGHTING/RESCUE/SAFETY EQUIPMENT; ENVIRON PROTECT EQUIPMENT/MATLS'
#  'SALVAGE- DEMOLITION OF STRUCTURES/FACILITIES (OTHER THAN BUILDINGS)'
#  'MODIFICATION OF EQUIPMENT- CONSTRUCTION, MINING, EXCAVATING, AND HIGHWAY MAINTENANCE EQUIPMENT'
#  'HAZARDOUS MATERIAL SPILL CONTAINMENT AND CLEAN-UP EQUIPMENT AND MATERIAL'
#  'INSPECTION- NONMETALLIC FABRICATED MATERIALS'
#  'DIESEL ENGINES AND COMPONENTS'
#  'REPAIR OR ALTERATION OF MAINTENANCE BUILDINGS'
#  'CONSTRUCTION OF SHIP CONSTRUCTION AND REPAIR FACILITIES'
#  'R&D- ENVIRONMENTAL PROTECTION: POLLUTION CONTROL/ABATEMENT (ENGINEERING DEVELOPMENT)'
#  'MAINTENANCE OF OTHER NON-BUILDING FACILITIES' 'UTILITIES- WATER'
#  'CRUDE GRADES OF PLANT MATERIALS' 'MISCELLANEOUS ITEMS'
#  'MAINT/REPAIR/REBUILD OF EQUIPMENT- PIPE, TUBING, HOSE, AND FITTINGS'
#  'NONMETALLIC SCRAP, EXCEPT TEXTILE'
#  'ARCHITECT AND ENGINEERING- CONSTRUCTION: MUSEUMS AND EXHIBITION BUILDINGS'
#  'ARCHITECT AND ENGINEERING- GENERAL: PLUMBING SYSTEMS'
#  'SUPPORT- ADMINISTRATIVE: OTHER'
#  'EQUIPMENT AND MATERIALS TESTING- CONSTRUCTION AND BUILDING MATERIALS'
#  'GENERATORS AND GENERATOR SETS, ELECTRICAL'
#  'LEASE/RENTAL OF CONFERENCE SPACE AND FACILITIES'
#  'SPECIAL STUDIES/ANALYSIS- WATER QUALITY'
#  'TRANSPORTATION/TRAVEL/RELOCATION- TRANSPORTATION: AIR FREIGHT'
#  'EDUCATION/TRAINING- VOCATIONAL/TECHNICAL' 'MACHINE TOOL ACCESSORIES'
#  'MAINTENANCE OF SHIP CONSTRUCTION AND REPAIR FACILITIES'
#  'SPECIAL STUDIES/ANALYSIS- ECONOMIC'
#  'INTERCOMMUNICATION AND PUBLIC ADDRESS SYSTEMS, AIRBORNE'
#  'SUPPORT- MANAGEMENT: DATA COLLECTION'
#  'MISCELLANEOUS MATERIALS HANDLING EQUIPMENT' 'TEXTILE FABRICS'
#  'CONSTRUCTION OF FUEL SUPPLY FACILITIES'
#  'REPAIR OR ALTERATION OF SURFACE MINE RECLAMATION FACILITIES'
#  'PEST CONTROL AGENTS AND DISINFECTANTS'
#  'ARCHITECT AND ENGINEERING- CONSTRUCTION: OTHER WAREHOUSE BUILDINGS'
#  'R&D- MINING: SUBSURFACE MINING METHODS (BASIC RESEARCH)'
#  'IT AND TELECOM - BUSINESS APPLICATION SOFTWARE (PERPETUAL LICENSE SOFTWARE)'
#  'R&D- ENERGY: PETROLEUM (BASIC RESEARCH)'
#  'MAINT/REPAIR/REBUILD OF EQUIPMENT- AIRCRAFT LAUNCHING, LANDING, AND GROUND HANDLING EQUIPMENT'
#  'SUPPORT- PROFESSIONAL: HUMAN RESOURCES'
#  'EQUIPMENT AND MATERIALS TESTING- PUMPS AND COMPRESSORS'
#  'LUBRICATION AND FUEL DISPENSING EQUIPMENT'
#  'TRACTOR, FULL TRACKED, LOW SPEED'
#  'EDUCATION/TRAINING- TUITION/REGISTRATION/MEMBERSHIP FEES'
#  'LEASE/RENTAL OF OFFICE BUILDINGS'
#  'MAINT/REPAIR/REBUILD OF EQUIPMENT- PUMPS AND COMPRESSORS'
#  'ENVIRONMENTAL SYSTEMS PROTECTION- TOXIC AND HAZARDOUS SUBSTANCE ANALYSIS'
#  'REPAIR OR ALTERATION OF OTHER RESIDENTIAL BUILDINGS'
#  'OPERATION OF FAMILY HOUSING FACILITIES'
#  'ARCHITECT AND ENGINEERING- CONSTRUCTION: WATER SUPPLY FACILITIES'
#  'OFFICE FURNITURE' 'MAINTENANCE OF OFFICE BUILDINGS'
#  'REPAIR OR ALTERATION OF DAMS'
#  'EQUIPMENT AND MATERIALS TESTING- INSTRUMENTS AND LABORATORY EQUIPMENT'
#  'ROAD CLEARING, CLEANING, AND MARKING EQUIPMENT'
#  'PETROLEUM PRODUCTION AND DISTRIBUTION EQUIPMENT'
#  'STIMULATED COHERENT RADIATION DEVICES, COMPONENTS, AND ACCESSORIES'
#  'ARCHITECT AND ENGINEERING- CONSTRUCTION: EXHIBIT DESIGN (NON-BUILDING)'
#  'SHIP AND BOAT PROPULSION COMPONENTS'
#  'MAINT/REPAIR/REBUILD OF EQUIPMENT- HOUSEHOLD AND COMMERCIAL FURNISHINGS AND APPLIANCES'
#  'SUPPORT- PROFESSIONAL: COMMUNICATIONS'
#  'PURCHASE OF WASTE TREATMENT AND STORAGE FACILITIES'
#  'HOUSEKEEPING- SOLID FUEL HANDLING'
#  'ENVIRONMENTAL SYSTEMS PROTECTION- ENVIRONMENTAL CONSULTING AND LEGAL SUPPORT'
#  'SPECIAL STUDIES/ANALYSIS- ENERGY'
#  'MISCELLANEOUS ENGINE ACCESSORIES, NONAIRCRAFT'
#  'ENGINE FUEL SYSTEM COMPONENTS, NONAIRCRAFT'
#  'LIQUID PROPELLANT FUELS AND OXIDIZERS, CHEMICAL BASE'
#  'PARACHUTES; AERIAL PICK UP, DELIVERY, RECOVERY SYSTEMS; AND CARGO TIE DOWN EQUIPMENT'
#  'MAINTENANCE OF SCHOOLS'
#  'QUALITY CONTROL- CONSTRUCTION, MINING, EXCAVATING, AND HIGHWAY MAINTENANCE EQUIPMENT'
#  'ARCHITECT AND ENGINEERING- CONSTRUCTION: TANK AUTOMOTIVE FACILITIES'
#  'SPECIALIZED AMMUNITION HANDLING AND SERVICING EQUIPMENT'
#  'OTHER QC/TEST/INSPECT- MATERIALS HANDLING EQUIPMENT'
#  'R&D- GENERAL SCIENCE/TECHNOLOGY: ENGINEERING (ENGINEERING DEVELOPMENT)'
#  'ARCHITECT AND ENGINEERING- CONSTRUCTION: SEWAGE AND WASTE FACILITIES'
#  'ELECTRIC ARC WELDING EQUIPMENT' 'HOUSEKEEPING- CARPET LAYING/CLEANING'
#  'REPAIR OR ALTERATION OF EPG FACILITIES - GAS'
#  'CONSTRUCTION OF OTHER AIRFIELD STRUCTURES' 'SMALL CRAFT'
#  'REPAIR OR ALTERATION OF OTHER UTILITIES'
#  'INSTALLATION OF EQUIPMENT- FUELS, LUBRICANTS, OILS, AND WAXES'
#  'HARVESTING EQUIPMENT' 'SUPPORT- ADMINISTRATIVE: PAPER SHREDDING'
#  'FLOOR COVERINGS'
#  'ARCHITECT AND ENGINEERING- CONSTRUCTION: OTHER INDUSTRIAL BUILDINGS'
#  'GAS GENERATING AND DISPENSING SYSTEMS, FIXED OR MOBILE'
#  'COMMERCIAL AND INDUSTRIAL GAS CYLINDERS' 'HOUSEKEEPING- GUARD'
#  'IT AND TELECOM- TELECOMMUNICATIONS NETWORK MANAGEMENT'
#  'MODIFICATION OF EQUIPMENT- ADP EQUIPMENT/SOFTWARE/SUPPLIES/SUPPORT EQUIPMENT'
#  'NATURAL RESOURCES/CONSERVATION- RECREATION SITE MAINTENANCE (NON-CONSTRUCTION)'
#  'INSPECTION- ORES, MINERALS, AND THEIR PRIMARY PRODUCTS'
#  'NATURAL RESOURCES/CONSERVATION- SURVEY LINE CLEARING'
#  'CUTLERY AND FLATWARE' 'SAFETY AND RESCUE EQUIPMENT'
#  'INSPECTION- FUELS, LUBRICANTS, OILS, AND WAXES'
#  'ARCHITECT AND ENGINEERING- GENERAL: STRUCTURAL ENGINEERING'
#  'HAND TOOLS, NONEDGED, NONPOWERED'
#  'ARCHITECT AND ENGINEERING- CONSTRUCTION: DAMS'
#  'ARCHITECT AND ENGINEERING- GENERAL: LANDSCAPING, INTERIOR LAYOUT, AND DESIGNING'
#  'ARCHITECT AND ENGINEERING- CONSTRUCTION: AIR TRAFFIC CONTROL TRAINING FACILITIES'
#  'TECHNICAL REPRESENTATIVE- MISCELLANEOUS' 'PASSENGER MOTOR VEHICLES'
#  'REPAIR OR ALTERATION OF TUNNELS AND SUBSURFACE STRUCTURES'
#  'ARCHITECT AND ENGINEERING- CONSTRUCTION: AMMUNITION FACILITIES'
#  'MAINT/REPAIR/REBUILD OF EQUIPMENT- SERVICE AND TRADE EQUIPMENT'
#  'REPAIR OR ALTERATION OF OFFICE BUILDINGS' 'BOLTS'
#  'ENVIRONMENTAL SYSTEMS PROTECTION- ENVIRONMENTAL LICENSING AND PERMITTING'
#  'ARCHITECT AND ENGINEERING- CONSTRUCTION: HEATING AND COOLING PLANTS'
#  'CONSTRUCTION OF DINING FACILITIES'
#  'MAINTENANCE OF CONFERENCE SPACE AND FACILITIES'
#  'CONSTRUCTION OF EPG FACILITIES - COAL'
#  'ELECTRICAL AND ELECTRONIC ASSEMBLIES, BOARDS, CARDS, AND ASSOCIATED HARDWARE'
#  'HOSE, PIPE, TUBE, LUBRICATION, AND RAILING FITTINGS'
#  'CONSTRUCTION OF EPG FACILITIES - WIND' 'KITCHEN HAND TOOLS AND UTENSILS'
#  'R&D- ENERGY: PETROLEUM (APPLIED RESEARCH/EXPLORATORY DEVELOPMENT)'
#  'MISCELLANEOUS ELECTRIC POWER AND DISTRIBUTION EQUIPMENT'
#  'SPECIAL STUDIES/ANALYSIS- ARCHEOLOGICAL/PALEONTOLOGICAL'
#  'INDOOR AND OUTDOOR ELECTRIC LIGHTING FIXTURES'
#  'OPERATION OF FUEL SUPPLY FACILITIES' 'DYES'
#  'MAINT/REPAIR/REBUILD OF EQUIPMENT- SHIP AND MARINE EQUIPMENT'
#  'NATURAL RESOURCES/CONSERVATION- FOREST TREE PLANTING'
#  'EQUIPMENT AND MATERIALS TESTING- PLUMBING, HEATING, AND WASTE DISPOSAL EQUIPMENT'
#  'AIRCRAFT MAINTENANCE AND REPAIR SHOP SPECIALIZED EQUIPMENT'
#  "COLLECTORS' AND/OR HISTORICAL ITEMS" 'BARGES AND LIGHTERS, CARGO'
#  'QUALITY CONTROL- MEASURING TOOLS' 'BOXES, CARTONS, AND CRATES'
#  'VEHICULAR CAB, BODY, AND FRAME STRUCTURAL COMPONENTS'
#  'EDUCATION/TRAINING- INFORMATION TECHNOLOGY/TELECOMMUNICATIONS TRAINING'
#  'REPAIR OR ALTERATION OF SEWAGE AND WASTE FACILITIES'
#  'TECHNICAL REPRESENTATIVE- CONSTRUCTION/MINING/EXCAVATING/HIGHWAY MAINT EQUIP'
#  'IT AND TELECOM- ANNUAL SOFTWARE MAINTENANCE SERVICE PLANS'
#  'MISCELLANEOUS CRUDE AGRICULTURAL AND FORESTRY PRODUCTS'
#  'IT AND TELECOM- IT STRATEGY AND ARCHITECTURE'
#  'LEASE/RENTAL OF FUEL STORAGE BUILDINGS'
#  'HAZARD-DETECTING INSTRUMENTS AND APPARATUS'
#  'SUPPORT- MANAGEMENT: ADVERTISING'
#  'MAINTENANCE OF ELECTRONIC AND COMMUNICATIONS FACILITIES'
#  'PURCHASE OF DAMS' 'IT AND TELECOM- OPTICAL SCANNING'
#  'ARCHITECT AND ENGINEERING- CONSTRUCTION: PARKING FACILITIES'
#  'NONFERROUS BASE METAL REFINERY AND INTERMEDIATE FORMS']

# %%
# Relevant product or service code descriptions
# 'GASES: COMPRESSED AND LIQUEFIED' 'NATURAL RESOURCES/CONSERVATION- WELL DRILLING/EXPLORATORY' 'UTILITIES- GAS' 'LIQUID AND GAS FLOW, LIQUID LEVEL, AND MECHANICAL MOTION MEASURING INSTRUMENTS' 
# 'MAINTENANCE OF FUEL SUPPLY FACILITIES' 'CONSTRUCTION OF EPG FACILITIES - GAS' 'NATURAL RESOURCES/CONSERVATION- SITE PREPARATION' 'REPAIR OR ALTERATION OF FUEL SUPPLY FACILITIES' 'CONSTRUCTION OF FUEL SUPPLY FACILITIES'
# 'R&D- ENERGY: GAS (BASIC RESEARCH)' 'GAS GENERATING AND DISPENSING SYSTEMS, FIXED OR MOBILE' 'REPAIR OR ALTERATION OF EPG FACILITIES - GAS' 'ENERGY R&D SERVICES; EMERGENCY ENERGY PREPAREDNESS; BASIC RESEARCH'

# %%
# Month vs Natural Gas Price Scatterplot
natural_gas_data_df1.plot.scatter(x = "Month", y = "Natural gas, US", s = 10, c = "blue")

# %%
# Month vs Contract Amounts
natural_gas_data_df1.plot.scatter(x = "Month", y = "total_obligated_amount", c='green')

# %%
# Month vs Contract Amounts
natural_gas_data_df1.dtypes
# Out:
# Month                                   object
# naics_description                       object
# product_or_service_code_description     object
# total_obligated_amount                 float64
# recipient_name                          object
# funding_sub_agency_name                 object
# Natural gas, US                        float64
# dtype: object

# %%
natural_gas_data_df1.count()
# Out:
# Month                                  10580
# naics_description                      10580
# product_or_service_code_description    10580
# total_obligated_amount                 10580
# recipient_name                         10547
# funding_sub_agency_name                10580
# Natural gas, US                        10580
# dtype: int64

# %%
natural_gas_data_df1.isnull().sum()
# Out:
# Month                                   0
# naics_description                       0
# product_or_service_code_description     0
# total_obligated_amount                  0
# recipient_name                         33
# funding_sub_agency_name                 0
# Natural gas, US                         0
# dtype: int64

# %%
#natural_gas_data_df1.plot(x= "Month", y="Natural gas, US")
#plt.show()

# %%
natural_gas_data_df2.plot(x= "yyyy", y="Natural gas, US")

# %%
# 11/21/2022

# temp_df1 = pd.DataFrame(avg_gas_price["Natural gas, US"])
# temp_df1.index.get_level_values(0)

# temp_df1.plot(x=index.get_level_values(0), y="Natural gas, US", figsize=(15,10))

# %%
avg_gas_price["Natural gas, US"].plot(x= "yyyy", y="Natural gas, US", figsize=(15,10), title="US Natural Gas Price per Year", xlabel="Date", ylabel="US Natural Gas Price ($)")

# %%
natural_gas_data_df3.plot(x= "yyyy", y="Natural gas, US", figsize=(20, 10))

# %%
natural_gas_data_df1.plot.bar(x= "Month", y="Natural gas, US")
# Out:
# Error in callback <function flush_figures at 0x7f318a031050> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ---> 43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44             )
#      45     finally:
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2098                            else suppress())
#    2099                     with ctx:
# -> 2100                         self.figure.draw(renderer)
#    2101                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#    2102                     bbox_inches = self.figure.get_tightbbox(renderer,
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    1734             self.patch.draw(renderer)
#    1735             mimage._draw_list_compositing_images(
# -> 1736                 renderer, self, artists, self.suppressComposite)
#    1737
#    1738             renderer.close_group('figure')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     135     if not_composite or not has_images:
#     136         for a in artists:
# --> 137             a.draw(renderer)
#     138     else:
#     139         # Composite any adjacent images together
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2628             renderer.stop_rasterizing()
#    2629
# -> 2630         mimage._draw_list_compositing_images(renderer, self, artists)
#    2631
#    2632         renderer.close_group('axes')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     135     if not_composite or not has_images:
#     136         for a in artists:
# --> 137             a.draw(renderer)
#     138     else:
#     139         # Composite any adjacent images together
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1230
#    1231         for tick in ticks_to_draw:
# -> 1232             tick.draw(renderer)
#    1233
#    1234         # scale up the axis label box to also find the neighbors, not
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axis.py in draw(self, renderer)
#     295         for artist in [self.gridline, self.tick1line, self.tick2line,
#     296                        self.label1, self.label2]:
# --> 297             artist.draw(renderer)
#     298         renderer.close_group(self.__name__)
#     299         self.stale = False
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/text.py in draw(self, renderer)
#     704             gc.set_alpha(textobj.get_alpha())
#     705             gc.set_url(textobj._url)
# --> 706             textobj._set_gc_clip(gc)
#     707
#     708             angle = textobj.get_rotation()
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/artist.py in _set_gc_clip(self, gc)
#     861             if self.clipbox is not None:
#     862                 gc.set_clip_rectangle(self.clipbox)
# --> 863             gc.set_clip_path(self._clippath)
#     864         else:
#     865             gc.set_clip_rectangle(None)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/backend_bases.py in set_clip_path(self, path)
#     908         """
#     909         cbook._check_isinstance((transforms.TransformedPath, None), path=path)
# --> 910         self._clippath = path
#     911
#     912     def set_dashes(self, dash_offset, dash_list):
#
# KeyboardInterrupt:

# %%
natural_gas_data_df2.plot(x= "mm", y="Natural gas, US")
# adjust x-axis ticks here/define them / markers would look better in years

# %%
natural_gas_data_df2
# Out:
#          Month                              naics_description  \
# 0      2016M09                  NATURAL GAS LIQUID EXTRACTION
# 2      2017M05  SUPPORT ACTIVITIES FOR OIL AND GAS OPERATIONS
# 13     2020M09  SUPPORT ACTIVITIES FOR OIL AND GAS OPERATIONS
# 16     2017M01  SUPPORT ACTIVITIES FOR OIL AND GAS OPERATIONS
# 19     2016M10     CRUDE PETROLEUM AND NATURAL GAS EXTRACTION
# ...        ...                                            ...
# 10543  2020M12                  NATURAL GAS LIQUID EXTRACTION
# 10544  2018M06     CRUDE PETROLEUM AND NATURAL GAS EXTRACTION
# 10545  2017M07  SUPPORT ACTIVITIES FOR OIL AND GAS OPERATIONS
# 10564  2017M12     CRUDE PETROLEUM AND NATURAL GAS EXTRACTION
# 10567  2020M04  SUPPORT ACTIVITIES FOR OIL AND GAS OPERATIONS
#
#                      product_or_service_code_description  \
# 0                        GASES: COMPRESSED AND LIQUEFIED
# 2                  MAINTENANCE OF FUEL SUPPLY FACILITIES
# 13                                             FUEL OILS
# 16                                             FUEL OILS
# 19                       GASES: COMPRESSED AND LIQUEFIED
# ...                                                  ...
# 10543                    GASES: COMPRESSED AND LIQUEFIED
# 10544                    GASES: COMPRESSED AND LIQUEFIED
# 10545  SALVAGE- DEMOLITION OF STRUCTURES/FACILITIES (...
# 10564                    GASES: COMPRESSED AND LIQUEFIED
# 10567  MAINT/REPAIR/REBUILD OF EQUIPMENT- FUELS, LUBR...
#
#        total_obligated_amount                               recipient_name  \
# 0                    10000.00                       AMERIGAS PROPANE, L.P.
# 2                   542491.46                       POND CONSTRUCTORS, INC
# 13                    6872.28             LAUREL FUEL OIL & HEATING CO INC
# 16                    6960.00                           SLATER OIL COMPANY
# 19                   33593.68  CONSTELLATION NEWENERGY - GAS DIVISION, LLC
# ...                       ...                                          ...
# 10543                   98.00                                   GIGA, INC.
# 10544                 2099.65               MISCELLANEOUS FOREIGN AWARDEES
# 10545                58567.00              TALIB SYED AND ASSOCIATES, INC.
# 10564                34077.90        DIRECT ENERGY BUSINESS MARKETING, LLC
# 10567                 6000.00                CITI APPROVED ENTERPRISE, LLC
#
#            funding_sub_agency_name  Natural gas, US  mm  yyyy
# 0                 DEPT OF THE NAVY             2.97  09  2016
# 2         DEFENSE LOGISTICS AGENCY             3.12  05  2017
# 13        PUBLIC BUILDINGS SERVICE             1.92  09  2020
# 16           INDIAN HEALTH SERVICE             3.26  01  2017
# 19                DEPT OF THE ARMY             2.95  10  2016
# ...                            ...              ...  ..   ...
# 10543  FEDERAL ACQUISITION SERVICE             2.54  12  2020
# 10544             DEPT OF THE ARMY             2.95  06  2018
# 10545    BUREAU OF LAND MANAGEMENT             2.96  07  2017
# 10564             DEPT OF THE ARMY             2.76  12  2017
# 10567             U.S. COAST GUARD             1.74  04  2020
#
# [1889 rows x 9 columns]

# %%
# Remove 0's & create new DF3
natural_gas_data_df3= natural_gas_data_df2[natural_gas_data_df2['total_obligated_amount']!=0]

# %%
natural_gas_data_df3
# Out:
#          Month                              naics_description  \
# 0      2016M09                  NATURAL GAS LIQUID EXTRACTION
# 2      2017M05  SUPPORT ACTIVITIES FOR OIL AND GAS OPERATIONS
# 13     2020M09  SUPPORT ACTIVITIES FOR OIL AND GAS OPERATIONS
# 16     2017M01  SUPPORT ACTIVITIES FOR OIL AND GAS OPERATIONS
# 19     2016M10     CRUDE PETROLEUM AND NATURAL GAS EXTRACTION
# ...        ...                                            ...
# 10543  2020M12                  NATURAL GAS LIQUID EXTRACTION
# 10544  2018M06     CRUDE PETROLEUM AND NATURAL GAS EXTRACTION
# 10545  2017M07  SUPPORT ACTIVITIES FOR OIL AND GAS OPERATIONS
# 10564  2017M12     CRUDE PETROLEUM AND NATURAL GAS EXTRACTION
# 10567  2020M04  SUPPORT ACTIVITIES FOR OIL AND GAS OPERATIONS
#
#                      product_or_service_code_description  \
# 0                        GASES: COMPRESSED AND LIQUEFIED
# 2                  MAINTENANCE OF FUEL SUPPLY FACILITIES
# 13                                             FUEL OILS
# 16                                             FUEL OILS
# 19                       GASES: COMPRESSED AND LIQUEFIED
# ...                                                  ...
# 10543                    GASES: COMPRESSED AND LIQUEFIED
# 10544                    GASES: COMPRESSED AND LIQUEFIED
# 10545  SALVAGE- DEMOLITION OF STRUCTURES/FACILITIES (...
# 10564                    GASES: COMPRESSED AND LIQUEFIED
# 10567  MAINT/REPAIR/REBUILD OF EQUIPMENT- FUELS, LUBR...
#
#        total_obligated_amount                               recipient_name  \
# 0                    10000.00                       AMERIGAS PROPANE, L.P.
# 2                   542491.46                       POND CONSTRUCTORS, INC
# 13                    6872.28             LAUREL FUEL OIL & HEATING CO INC
# 16                    6960.00                           SLATER OIL COMPANY
# 19                   33593.68  CONSTELLATION NEWENERGY - GAS DIVISION, LLC
# ...                       ...                                          ...
# 10543                   98.00                                   GIGA, INC.
# 10544                 2099.65               MISCELLANEOUS FOREIGN AWARDEES
# 10545                58567.00              TALIB SYED AND ASSOCIATES, INC.
# 10564                34077.90        DIRECT ENERGY BUSINESS MARKETING, LLC
# 10567                 6000.00                CITI APPROVED ENTERPRISE, LLC
#
#            funding_sub_agency_name  Natural gas, US  mm  yyyy
# 0                 DEPT OF THE NAVY             2.97  09  2016
# 2         DEFENSE LOGISTICS AGENCY             3.12  05  2017
# 13        PUBLIC BUILDINGS SERVICE             1.92  09  2020
# 16           INDIAN HEALTH SERVICE             3.26  01  2017
# 19                DEPT OF THE ARMY             2.95  10  2016
# ...                            ...              ...  ..   ...
# 10543  FEDERAL ACQUISITION SERVICE             2.54  12  2020
# 10544             DEPT OF THE ARMY             2.95  06  2018
# 10545    BUREAU OF LAND MANAGEMENT             2.96  07  2017
# 10564             DEPT OF THE ARMY             2.76  12  2017
# 10567             U.S. COAST GUARD             1.74  04  2020
#
# [1691 rows x 9 columns]

# %%
natural_gas_data_df3.to_csv('natural_gas_data_df3.csv')

# %%
avg_gas_price = natural_gas_data_df3.groupby(["yyyy", "mm"]).mean()
avg_gas_price["Natural gas, US"]
# Out:
# yyyy  mm
# 2016  01    2.27
#       02    1.96
#       03    1.70
#       04    1.90
#       05    1.92
#             ...
# 2021  05    2.89
#       06    3.23
#       07    3.80
#       08    4.05
#       09    5.11
# Name: Natural gas, US, Length: 69, dtype: float64

# %%
#avg_gas_price_year = avg_gas_price["Natural gas, US"].index[:,0]
#avg_gas_price_year

# %%
natural_gas_data_df3.info(verbose=True)

# %%
# remove total_obligated_amount 0's, by changing 0's to nan, then remove nan rows
#natural_gas_data_df2.replace(0, np.nan, inplace=True)
#natural_gas_data_df2

# %%
# # of 0's in dataframe
count_zeroes_df2 = (natural_gas_data_df2['total_obligated_amount'] == 0).sum()
count_zeroes_df3 = (natural_gas_data_df3['total_obligated_amount'] == 0).sum()
print(count_zeroes_df2)
print(count_zeroes_df3)
# Out:
# 198
# 0

# %%
# Find outliers / create bins

# %%
# contract toals
total_contract_amount = natural_gas_data_df2["total_obligated_amount"].sum()
total_contract_amount
# Out:
# 804215367.94

# %%
# agency names
agency_count = natural_gas_data_df2["funding_sub_agency_name"].unique()
agency_count
# Out:
# array(['DEPT OF THE NAVY', 'DEFENSE LOGISTICS AGENCY',
#        'PUBLIC BUILDINGS SERVICE', 'INDIAN HEALTH SERVICE',
#        'DEPT OF THE ARMY', 'MARITIME ADMINISTRATION',
#        'FEDERAL ACQUISITION SERVICE',
#        'FEDERAL PRISON SYSTEM / BUREAU OF PRISONS',
#        'J. F. KENNEDY CENTER FOR THE PERFORMING ARTS',
#        'BUREAU OF LAND MANAGEMENT', 'STATE, DEPARTMENT OF',
#        'ENERGY, DEPARTMENT OF', 'VETERANS AFFAIRS, DEPARTMENT OF',
#        'DEPT OF THE AIR FORCE', 'U.S. COAST GUARD',
#        'AGRICULTURAL RESEARCH SERVICE', 'U.S. FISH AND WILDLIFE SERVICE',
#        'BUREAU OF INDIAN AFFAIRS AND BUREAU OF INDIAN EDUCATION',
#        'UNITED STATES AGENCY FOR GLOBAL MEDIA, BBG',
#        'FEDERAL BUREAU OF INVESTIGATION',
#        'BUREAU OF SAFETY AND ENVIRONMENTAL ENFORCEMENT',
#        'NATIONAL PARK SERVICE',
#        'NATIONAL AERONAUTICS AND SPACE ADMINISTRATION',
#        'AGENCY FOR INTERNATIONAL DEVELOPMENT',
#        'FEDERAL AVIATION ADMINISTRATION',
#        'NATIONAL OCEANIC AND ATMOSPHERIC ADMINISTRATION',
#        'US GEOLOGICAL SURVEY', 'FEDERAL EMERGENCY MANAGEMENT AGENCY',
#        'INTERNAL REVENUE SERVICE', 'FEDERAL PRISON SYSTEM',
#        'RAILROAD RETIREMENT BOARD', 'OFFICES, BOARDS AND DIVISIONS',
#        'GAO, EXCEPT COMPTROLLER GENERAL', 'FOREST SERVICE',
#        'U.S. ARMY CORPS OF ENGINEERS - CIVIL PROGRAM FINANCING ONLY',
#        'BUREAU OF RECLAMATION', 'NATIONAL TRANSPORTATION SAFETY BOARD',
#        'CORPORATION FOR NATIONAL AND COMMUNITY SERVICE',
#        'NATIONAL INSTITUTES OF HEALTH', 'ENVIRONMENTAL PROTECTION AGENCY',
#        'FEDERAL LAW ENFORCEMENT TRAINING CENTER',
#        'BUREAU OF INDIAN AFFAIRS',
#        'NATURAL RESOURCES CONSERVATION SERVICE',
#        'CENTERS FOR DISEASE CONTROL AND PREVENTION',
#        'BUREAU OF OCEAN ENERGY MANAGEMENT',
#        'DRUG ENFORCEMENT ADMINISTRATION', 'SMITHSONIAN INSTITUTION'],
#       dtype=object)

# %%
agency_count = natural_gas_data_df2["funding_sub_agency_name"].value_counts()
agency_count
# Out:
# DEPT OF THE ARMY                                               535
# FEDERAL ACQUISITION SERVICE                                    395
# DEFENSE LOGISTICS AGENCY                                       176
# DEPT OF THE AIR FORCE                                          156
# STATE, DEPARTMENT OF                                           122
# FEDERAL PRISON SYSTEM / BUREAU OF PRISONS                       94
# VETERANS AFFAIRS, DEPARTMENT OF                                 92
# DEPT OF THE NAVY                                                72
# BUREAU OF LAND MANAGEMENT                                       36
# U.S. COAST GUARD                                                29
# US GEOLOGICAL SURVEY                                            22
# ENERGY, DEPARTMENT OF                                           16
# NATIONAL PARK SERVICE                                           16
# BUREAU OF SAFETY AND ENVIRONMENTAL ENFORCEMENT                  12
# NATIONAL AERONAUTICS AND SPACE ADMINISTRATION                   11
# BUREAU OF INDIAN AFFAIRS AND BUREAU OF INDIAN EDUCATION          9
# INDIAN HEALTH SERVICE                                            8
# FEDERAL LAW ENFORCEMENT TRAINING CENTER                          8
# RAILROAD RETIREMENT BOARD                                        7
# U.S. FISH AND WILDLIFE SERVICE                                   7
# FOREST SERVICE                                                   6
# NATIONAL OCEANIC AND ATMOSPHERIC ADMINISTRATION                  6
# INTERNAL REVENUE SERVICE                                         5
# U.S. ARMY CORPS OF ENGINEERS - CIVIL PROGRAM FINANCING ONLY      4
# NATIONAL INSTITUTES OF HEALTH                                    4
# FEDERAL AVIATION ADMINISTRATION                                  4
# AGRICULTURAL RESEARCH SERVICE                                    3
# FEDERAL PRISON SYSTEM                                            3
# J. F. KENNEDY CENTER FOR THE PERFORMING ARTS                     3
# NATURAL RESOURCES CONSERVATION SERVICE                           3
# BUREAU OF INDIAN AFFAIRS                                         3
# UNITED STATES AGENCY FOR GLOBAL MEDIA, BBG                       2
# FEDERAL EMERGENCY MANAGEMENT AGENCY                              2
# CENTERS FOR DISEASE CONTROL AND PREVENTION                       2
# MARITIME ADMINISTRATION                                          2
# PUBLIC BUILDINGS SERVICE                                         2
# BUREAU OF RECLAMATION                                            2
# BUREAU OF OCEAN ENERGY MANAGEMENT                                1
# DRUG ENFORCEMENT ADMINISTRATION                                  1
# AGENCY FOR INTERNATIONAL DEVELOPMENT                             1
# ENVIRONMENTAL PROTECTION AGENCY                                  1
# CORPORATION FOR NATIONAL AND COMMUNITY SERVICE                   1
# NATIONAL TRANSPORTATION SAFETY BOARD                             1
# GAO, EXCEPT COMPTROLLER GENERAL                                  1
# OFFICES, BOARDS AND DIVISIONS                                    1
# FEDERAL BUREAU OF INVESTIGATION                                  1
# SMITHSONIAN INSTITUTION                                          1
# Name: funding_sub_agency_name, dtype: int64

# %%
# Agency Count DF3
agency_count_df3 = natural_gas_data_df3["funding_sub_agency_name"].value_counts()
agency_count_df3
# Out:
# DEPT OF THE ARMY                                               506
# FEDERAL ACQUISITION SERVICE                                    383
# DEPT OF THE AIR FORCE                                          133
# STATE, DEPARTMENT OF                                           104
# FEDERAL PRISON SYSTEM / BUREAU OF PRISONS                       90
# VETERANS AFFAIRS, DEPARTMENT OF                                 90
# DEFENSE LOGISTICS AGENCY                                        88
# DEPT OF THE NAVY                                                68
# BUREAU OF LAND MANAGEMENT                                       34
# U.S. COAST GUARD                                                29
# US GEOLOGICAL SURVEY                                            18
# NATIONAL PARK SERVICE                                           16
# ENERGY, DEPARTMENT OF                                           12
# BUREAU OF SAFETY AND ENVIRONMENTAL ENFORCEMENT                  11
# NATIONAL AERONAUTICS AND SPACE ADMINISTRATION                   11
# BUREAU OF INDIAN AFFAIRS AND BUREAU OF INDIAN EDUCATION          8
# INDIAN HEALTH SERVICE                                            8
# FEDERAL LAW ENFORCEMENT TRAINING CENTER                          8
# RAILROAD RETIREMENT BOARD                                        7
# U.S. FISH AND WILDLIFE SERVICE                                   7
# NATIONAL OCEANIC AND ATMOSPHERIC ADMINISTRATION                  6
# INTERNAL REVENUE SERVICE                                         5
# FOREST SERVICE                                                   4
# FEDERAL AVIATION ADMINISTRATION                                  4
# FEDERAL PRISON SYSTEM                                            3
# J. F. KENNEDY CENTER FOR THE PERFORMING ARTS                     3
# U.S. ARMY CORPS OF ENGINEERS - CIVIL PROGRAM FINANCING ONLY      3
# NATURAL RESOURCES CONSERVATION SERVICE                           3
# BUREAU OF INDIAN AFFAIRS                                         3
# NATIONAL INSTITUTES OF HEALTH                                    3
# BUREAU OF RECLAMATION                                            2
# FEDERAL EMERGENCY MANAGEMENT AGENCY                              2
# UNITED STATES AGENCY FOR GLOBAL MEDIA, BBG                       2
# CENTERS FOR DISEASE CONTROL AND PREVENTION                       2
# MARITIME ADMINISTRATION                                          2
# PUBLIC BUILDINGS SERVICE                                         2
# ENVIRONMENTAL PROTECTION AGENCY                                  1
# DRUG ENFORCEMENT ADMINISTRATION                                  1
# BUREAU OF OCEAN ENERGY MANAGEMENT                                1
# AGENCY FOR INTERNATIONAL DEVELOPMENT                             1
# CORPORATION FOR NATIONAL AND COMMUNITY SERVICE                   1
# NATIONAL TRANSPORTATION SAFETY BOARD                             1
# FEDERAL BUREAU OF INVESTIGATION                                  1
# GAO, EXCEPT COMPTROLLER GENERAL                                  1
# OFFICES, BOARDS AND DIVISIONS                                    1
# AGRICULTURAL RESEARCH SERVICE                                    1
# SMITHSONIAN INSTITUTION                                          1
# Name: funding_sub_agency_name, dtype: int64

# %%
# put agencies w/ less than 10 into an 'other' category to clear up labels on charts
#other_adjusted_df = natural_gas_data_df3["funding_sub_agency_name"].replace(['BUREAU OF INDIAN AFFAIRS AND BUREAU OF INDIAN EDUCATION', 'INDIAN HEALTH SERVICE', 'FEDERAL LAW ENFORCEMENT TRAINING CENTER', 'RAILROAD RETIREMENT BOARD', 'U.S. FISH AND WILDLIFE SERVICE', 'NATIONAL OCEANIC AND ATMOSPHERIC ADMINISTRATION', 'INTERNAL REVENUE SERVICE', 'FOREST SERVICE', 'FEDERAL AVIATION ADMINISTRATION', 'FEDERAL PRISON SYSTEM', 'J. F. KENNEDY CENTER FOR THE PERFORMING ARTS', 'U.S. ARMY CORPS OF ENGINEERS - CIVIL PROGRAM FINANCING ONLY', 'NATURAL RESOURCES CONSERVATION SERVICE', 'BUREAU OF INDIAN AFFAIRS', 'NATIONAL INSTITUTES OF HEALTH', 'BUREAU OF RECLAMATION', 'FEDERAL EMERGENCY MANAGEMENT AGENCY', 'UNITED STATES AGENCY FOR GLOBAL MEDIA, BBG', 'CENTERS FOR DISEASE CONTROL AND PREVENTION', 'MARITIME ADMINISTRATION', 'PUBLIC BUILDINGS SERVICE', 'ENVIRONMENTAL PROTECTION AGENCY', 'DRUG ENFORCEMENT ADMINISTRATION', 'BUREAU OF OCEAN ENERGY MANAGEMENT', 'AGENCY FOR INTERNATIONAL DEVELOPMENT', 'CORPORATION FOR NATIONAL AND COMMUNITY SERVICE', 'NATIONAL TRANSPORTATION SAFETY BOARD', 'FEDERAL BUREAU OF INVESTIGATION', 'GAO, EXCEPT COMPTROLLER GENERAL', 'OFFICES, BOARDS AND DIVISIONS', 'AGRICULTURAL RESEARCH SERVICE', 'SMITHSONIAN INSTITUTION'], 
                                                                          #  ['Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other', 'Other'], inplace=False)

# %%
#other_adjusted_df

# %%
#count_other_adjusted_df = other_adjusted_df.index.value_counts()
#count_other_adjusted_df

# %%
# natural_gas_df3 types
natural_gas_data_df3.dtypes
# Out:
# Month                                   object
# naics_description                       object
# product_or_service_code_description     object
# total_obligated_amount                 float64
# recipient_name                          object
# funding_sub_agency_name                 object
# Natural gas, US                        float64
# mm                                      object
# yyyy                                    object
# dtype: object

# %%
# Other Natural Gas DF Count
agency_other_count_df = other_natural_gas_df["funding_sub_agency_name"].value_counts()
agency_other_count_df
# Out:
# DEPT OF THE ARMY                                  506
# FEDERAL ACQUISITION SERVICE                       383
# DEPT OF THE AIR FORCE                             133
# STATE, DEPARTMENT OF                              104
# OTHER                                              95
# FEDERAL PRISON SYSTEM / BUREAU OF PRISONS          93
# VETERANS AFFAIRS, DEPARTMENT OF                    90
# DEFENSE LOGISTICS AGENCY                           88
# DEPT OF THE NAVY                                   68
# BUREAU OF LAND MANAGEMENT                          34
# U.S. COAST GUARD                                   29
# US GEOLOGICAL SURVEY                               18
# NATIONAL PARK SERVICE                              16
# ENERGY, DEPARTMENT OF                              12
# BUREAU OF SAFETY AND ENVIRONMENTAL ENFORCEMENT     11
# NATIONAL AERONAUTICS AND SPACE ADMINISTRATION      11
# Name: funding_sub_agency_name, dtype: int64

# %%
# Horizontal Bar Plot
agency_other_count_df.plot.barh(title="Number of Contracts Awarded by Agency", ylabel="# of Contracts", xlabel="Agency", figsize=(15,10))

# %%
# Plot Contract Amount & Agency
funding_agency_df = other_natural_gas_df.groupby("funding_sub_agency_name").sum()["total_obligated_amount"]
# sort_values(by="total_obligated_amount", ascending=False)
funding_agency_df = funding_agency_df.sort_values(ascending=False)

# %%
# Plot Contract Amount vs Agency
funding_agency_df.plot.barh(title="Value of Contracts ($ Hundred Million) Awarded by Agency", ylabel="Value of Contract ($)", xlabel="Agency Name", figsize=(15,10), color="green")

# %%
# Scatter Plot Agency Count of Contracts vs Mean Value of Contracts
scatter_agency_mean_value_df = natural_gas_data_df3.groupby("funding_sub_agency_name").mean()
scatter_agency_mean_value_df = scatter_agency_mean_value_df.join(agency_count_df3, on=scatter_agency_mean_value_df.index)

# %%
scatter_agency_mean_value_df.columns=["Average Contract Amount", "Average US Gas Price", "Contract Count"]
scatter_agency_mean_value_df
# Out:
#                                                     Average Contract Amount  \
# funding_sub_agency_name
# AGENCY FOR INTERNATIONAL DEVELOPMENT                           1.171110e+04
# AGRICULTURAL RESEARCH SERVICE                                  3.456398e+04
# BUREAU OF INDIAN AFFAIRS                                       1.173786e+05
# BUREAU OF INDIAN AFFAIRS AND BUREAU OF INDIAN E...             2.583865e+04
# BUREAU OF LAND MANAGEMENT                                      8.209680e+05
# BUREAU OF OCEAN ENERGY MANAGEMENT                              9.180000e+04
# BUREAU OF RECLAMATION                                          1.438578e+05
# BUREAU OF SAFETY AND ENVIRONMENTAL ENFORCEMENT                 3.428866e+05
# CENTERS FOR DISEASE CONTROL AND PREVENTION                     6.929786e+04
# CORPORATION FOR NATIONAL AND COMMUNITY SERVICE                 2.600000e+04
# DEFENSE LOGISTICS AGENCY                                       5.108837e+06
# DEPT OF THE AIR FORCE                                          5.745353e+05
# DEPT OF THE ARMY                                               2.089828e+05
# DEPT OF THE NAVY                                               8.188693e+04
# DRUG ENFORCEMENT ADMINISTRATION                                2.700000e+03
# ENERGY, DEPARTMENT OF                                          5.295555e+06
# ENVIRONMENTAL PROTECTION AGENCY                                7.500000e+04
# FEDERAL ACQUISITION SERVICE                                    1.936971e+02
# FEDERAL AVIATION ADMINISTRATION                                6.744999e+04
# FEDERAL BUREAU OF INVESTIGATION                                3.249970e+03
# FEDERAL EMERGENCY MANAGEMENT AGENCY                            1.157250e+04
# FEDERAL LAW ENFORCEMENT TRAINING CENTER                        1.219478e+05
# FEDERAL PRISON SYSTEM                                          7.617340e+03
# FEDERAL PRISON SYSTEM / BUREAU OF PRISONS                      1.802074e+05
# FOREST SERVICE                                                 1.239829e+04
# GAO, EXCEPT COMPTROLLER GENERAL                                8.975000e+04
# INDIAN HEALTH SERVICE                                          1.485851e+04
# INTERNAL REVENUE SERVICE                                       2.862898e+05
# J. F. KENNEDY CENTER FOR THE PERFORMING ARTS                   1.821490e+05
# MARITIME ADMINISTRATION                                        6.080525e+04
# NATIONAL AERONAUTICS AND SPACE ADMINISTRATION                  8.576346e+05
# NATIONAL INSTITUTES OF HEALTH                                  8.206147e+03
# NATIONAL OCEANIC AND ATMOSPHERIC ADMINISTRATION                1.579870e+04
# NATIONAL PARK SERVICE                                          1.390107e+05
# NATIONAL TRANSPORTATION SAFETY BOARD                           1.725700e+04
# NATURAL RESOURCES CONSERVATION SERVICE                         1.434733e+04
# OFFICES, BOARDS AND DIVISIONS                                  3.518023e+04
# PUBLIC BUILDINGS SERVICE                                       6.188008e+06
# RAILROAD RETIREMENT BOARD                                      4.849220e+04
# SMITHSONIAN INSTITUTION                                        9.154130e+03
# STATE, DEPARTMENT OF                                           1.750113e+04
# U.S. ARMY CORPS OF ENGINEERS - CIVIL PROGRAM FI...             4.157027e+05
# U.S. COAST GUARD                                               1.085363e+05
# U.S. FISH AND WILDLIFE SERVICE                                 2.002027e+04
# UNITED STATES AGENCY FOR GLOBAL MEDIA, BBG                     1.226589e+04
# US GEOLOGICAL SURVEY                                           5.255450e+04
# VETERANS AFFAIRS, DEPARTMENT OF                                2.064924e+05
#
#                                                     Average US Gas Price  \
# funding_sub_agency_name
# AGENCY FOR INTERNATIONAL DEVELOPMENT                            3.120000
# AGRICULTURAL RESEARCH SERVICE                                   1.920000
# BUREAU OF INDIAN AFFAIRS                                        2.533333
# BUREAU OF INDIAN AFFAIRS AND BUREAU OF INDIAN E...              2.800000
# BUREAU OF LAND MANAGEMENT                                       3.446765
# BUREAU OF OCEAN ENERGY MANAGEMENT                               1.920000
# BUREAU OF RECLAMATION                                           2.580000
# BUREAU OF SAFETY AND ENVIRONMENTAL ENFORCEMENT                  2.768182
# CENTERS FOR DISEASE CONTROL AND PREVENTION                      2.360000
# CORPORATION FOR NATIONAL AND COMMUNITY SERVICE                  2.990000
# DEFENSE LOGISTICS AGENCY                                        2.795682
# DEPT OF THE AIR FORCE                                           2.704962
# DEPT OF THE ARMY                                                2.793834
# DEPT OF THE NAVY                                                2.869118
# DRUG ENFORCEMENT ADMINISTRATION                                 3.800000
# ENERGY, DEPARTMENT OF                                           2.850000
# ENVIRONMENTAL PROTECTION AGENCY                                 1.920000
# FEDERAL ACQUISITION SERVICE                                     2.735770
# FEDERAL AVIATION ADMINISTRATION                                 2.705000
# FEDERAL BUREAU OF INVESTIGATION                                 3.120000
# FEDERAL EMERGENCY MANAGEMENT AGENCY                             2.640000
# FEDERAL LAW ENFORCEMENT TRAINING CENTER                         3.133750
# FEDERAL PRISON SYSTEM                                           1.766667
# FEDERAL PRISON SYSTEM / BUREAU OF PRISONS                       2.830556
# FOREST SERVICE                                                  2.892500
# GAO, EXCEPT COMPTROLLER GENERAL                                 1.920000
# INDIAN HEALTH SERVICE                                           2.803750
# INTERNAL REVENUE SERVICE                                        2.766000
# J. F. KENNEDY CENTER FOR THE PERFORMING ARTS                    2.733333
# MARITIME ADMINISTRATION                                         2.685000
# NATIONAL AERONAUTICS AND SPACE ADMINISTRATION                   2.554545
# NATIONAL INSTITUTES OF HEALTH                                   2.770000
# NATIONAL OCEANIC AND ATMOSPHERIC ADMINISTRATION                 2.906667
# NATIONAL PARK SERVICE                                           3.046250
# NATIONAL TRANSPORTATION SAFETY BOARD                            2.580000
# NATURAL RESOURCES CONSERVATION SERVICE                          2.323333
# OFFICES, BOARDS AND DIVISIONS                                   3.280000
# PUBLIC BUILDINGS SERVICE                                        2.445000
# RAILROAD RETIREMENT BOARD                                       2.537143
# SMITHSONIAN INSTITUTION                                         1.740000
# STATE, DEPARTMENT OF                                            2.995385
# U.S. ARMY CORPS OF ENGINEERS - CIVIL PROGRAM FI...              3.550000
# U.S. COAST GUARD                                                2.503793
# U.S. FISH AND WILDLIFE SERVICE                                  3.285714
# UNITED STATES AGENCY FOR GLOBAL MEDIA, BBG                      2.900000
# US GEOLOGICAL SURVEY                                            2.633889
# VETERANS AFFAIRS, DEPARTMENT OF                                 2.629333
#
#                                                     Contract Count
# funding_sub_agency_name
# AGENCY FOR INTERNATIONAL DEVELOPMENT                             1
# AGRICULTURAL RESEARCH SERVICE                                    1
# BUREAU OF INDIAN AFFAIRS                                         3
# BUREAU OF INDIAN AFFAIRS AND BUREAU OF INDIAN E...               8
# BUREAU OF LAND MANAGEMENT                                       34
# BUREAU OF OCEAN ENERGY MANAGEMENT                                1
# BUREAU OF RECLAMATION                                            2
# BUREAU OF SAFETY AND ENVIRONMENTAL ENFORCEMENT                  11
# CENTERS FOR DISEASE CONTROL AND PREVENTION                       2
# CORPORATION FOR NATIONAL AND COMMUNITY SERVICE                   1
# DEFENSE LOGISTICS AGENCY                                        88
# DEPT OF THE AIR FORCE                                          133
# DEPT OF THE ARMY                                               506
# DEPT OF THE NAVY                                                68
# DRUG ENFORCEMENT ADMINISTRATION                                  1
# ENERGY, DEPARTMENT OF                                           12
# ENVIRONMENTAL PROTECTION AGENCY                                  1
# FEDERAL ACQUISITION SERVICE                                    383
# FEDERAL AVIATION ADMINISTRATION                                  4
# FEDERAL BUREAU OF INVESTIGATION                                  1
# FEDERAL EMERGENCY MANAGEMENT AGENCY                              2
# FEDERAL LAW ENFORCEMENT TRAINING CENTER                          8
# FEDERAL PRISON SYSTEM                                            3
# FEDERAL PRISON SYSTEM / BUREAU OF PRISONS                       90
# FOREST SERVICE                                                   4
# GAO, EXCEPT COMPTROLLER GENERAL                                  1
# INDIAN HEALTH SERVICE                                            8
# INTERNAL REVENUE SERVICE                                         5
# J. F. KENNEDY CENTER FOR THE PERFORMING ARTS                     3
# MARITIME ADMINISTRATION                                          2
# NATIONAL AERONAUTICS AND SPACE ADMINISTRATION                   11
# NATIONAL INSTITUTES OF HEALTH                                    3
# NATIONAL OCEANIC AND ATMOSPHERIC ADMINISTRATION                  6
# NATIONAL PARK SERVICE                                           16
# NATIONAL TRANSPORTATION SAFETY BOARD                             1
# NATURAL RESOURCES CONSERVATION SERVICE                           3
# OFFICES, BOARDS AND DIVISIONS                                    1
# PUBLIC BUILDINGS SERVICE                                         2
# RAILROAD RETIREMENT BOARD                                        7
# SMITHSONIAN INSTITUTION                                          1
# STATE, DEPARTMENT OF                                           104
# U.S. ARMY CORPS OF ENGINEERS - CIVIL PROGRAM FI...               3
# U.S. COAST GUARD                                                29
# U.S. FISH AND WILDLIFE SERVICE                                   7
# UNITED STATES AGENCY FOR GLOBAL MEDIA, BBG                       2
# US GEOLOGICAL SURVEY                                            18
# VETERANS AFFAIRS, DEPARTMENT OF                                 90

# %%
scatter_agency_mean_value_df.plot.scatter(title= "Average Contract Value vs Number of Contracts Scatter Plot", x="Average Contract Amount", y="Contract Count", figsize=(15,10))

# %%
# pie chart of agency contracts awarded other_natural_gas_df
sums = other_natural_gas_df.groupby(other_natural_gas_df["funding_sub_agency_name"])["total_obligated_amount"].sum()
axis('equal');
fig = plt.pie(sums, labels=sums.index, radius=1.6);
plt.show()

# %%
# Other Natural Gas 10 DF Count
agency_other_count_10_df = other_natural_gas_10_df["funding_sub_agency_name"].value_counts()
agency_other_count_10_df
# Out:
# DEPT OF THE ARMY                             506
# FEDERAL ACQUISITION SERVICE                  383
# OTHER                                        192
# DEPT OF THE AIR FORCE                        133
# STATE, DEPARTMENT OF                         104
# FEDERAL PRISON SYSTEM / BUREAU OF PRISONS     93
# VETERANS AFFAIRS, DEPARTMENT OF               90
# DEFENSE LOGISTICS AGENCY                      88
# DEPT OF THE NAVY                              68
# BUREAU OF LAND MANAGEMENT                     34
# Name: funding_sub_agency_name, dtype: int64

# %%
# pie chart of agency contracts awarded other_natural_gas_10_df
sums = other_natural_gas_10_df.groupby(other_natural_gas_10_df["funding_sub_agency_name"])["total_obligated_amount"].sum()
axis('equal');
pie(sums, labels=sums.index, radius=3.0, rotatelabels = 180,
startangle=90, counterclock=False);
show()

# %%
# Other Natural Gas 5 DF Count
agency_other_count_5_df = other_natural_gas_5_df["funding_sub_agency_name"].value_counts()
agency_other_count_5_df

# %%
# pie chart of agency contracts awarded other_natural_gas_5_df
sums = other_natural_gas_5_df.groupby(other_natural_gas_5_df["funding_sub_agency_name"])["total_obligated_amount"].sum()
axis('equal');
pie(sums, labels=sums.index);
show()

# %%
# clean funding_sub_agency_name - repeating same agency name, reordering agency names
# Reorder Veterans Affairs & Dept of State - https://www.askpython.com/python-modules/pandas/update-the-value-of-a-row-dataframe | https://datagy.io/pandas-data-cleaning/
#natural_gas_data_df2["funding_sub_agency_name"] = natural_gas_data_df2["funding_sub_agency_name"].str.replace("VETERANS AFFAIRS, DEPARTMENT OF", "DEPARTMENT OF VETERANS AFFAIRS")
#natural_gas_data_df2.tail()

#natural_gas_data_df2.replace("STATE, DEPARTMENT OF", 
          # "DEPARTMENT OF STATE", 
           #inplace=True)
#natural_gas_data_df2

# clean repeating agency names

# %%
contracts_per_agency = natural_gas_data_df2.set_index(["funding_sub_agency_name"])["total_obligated_amount"]
contracts_per_agency

# %%
# Linear Regression
# Independent Variable (X) - contract price      Dependent Variable (Y) - natural gas price US
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on govt contract data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    
    print(r_value) 
    print(p_value)
    print("this is the r value", r_value)
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('US Govt Contract Value')
    plt.ylabel(y_label)
    plt.show()

# %%
x_values = natural_gas_data_df2["Natural gas, US"]
y_values = natural_gas_data_df2["total_obligated_amount"]

plot_linear_regression(x_values, y_values,
                       'Linear Regression on US Govt Contracts for US Natural Gas Prices', 'Natural gas, US',(10, 40))
# Out:
# 0.05457365863935613
# 0.017686709826085348
# this is the r value 0.05457365863935613

# %%
# summarize dataframe w/ groupby / time / department/recipient | look at source of outliers
# p value not statistically significant | r-value is weak too
# not a strong linear relationship as is | adjust

# %%
# Linear Regression of Army Contracts to US Natural Gas Prices

# %%
# Month vs Natural Gas Price Scatterplot
natural_gas_data_df2.plot.scatter(x = "yyyy", y = "Natural gas, US", s = 10, c = "blue")

# %%
# pie chart of agency contracts awarded df2
sums = natural_gas_data_df2.groupby(natural_gas_data_df2["funding_sub_agency_name"])["total_obligated_amount"].sum()
axis('equal');
pie(sums, labels=sums.index);
show()

# %%
# pie chart of agency contracts awarded df3
sums = natural_gas_data_df3.groupby(natural_gas_data_df3["funding_sub_agency_name"])["total_obligated_amount"].sum()
axis('equal');
pie(sums, labels=sums.index);
show()

# %%
natural_gas_data_df3.plot.scatter(x = "yyyy", y = "Natural gas, US", s = 10, c = "blue")

# %%
x_values = natural_gas_data_df3["Natural gas, US"]
y_values = natural_gas_data_df3["total_obligated_amount"]

plot_linear_regression(x_values, y_values,
                       'Linear Regression on US Govt Contracts \
                       for US Natural Gas Prices', 'Natural gas, US',(10, 40))
